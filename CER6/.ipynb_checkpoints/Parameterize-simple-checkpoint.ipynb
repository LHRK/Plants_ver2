# %%
from Parameterize import *
import nglview as ng

# %%
main_dir   = '/mnt/f/BILAYERS/CER6/gromacs_MAP2' #Main working directory, where the AA simulations are located as well
mdp_loc_BL = '/mnt/f/BILAYERS/MDPs' #This is default
mdp_loc    = '/mnt/f/AA_SIMS_WATER_IONS/MDPs'

## AA sim
GRO = 'CER6_POPC.gro'
TPR = 'CER6_POPC.tpr'
XTC = 'CER6_POPC.xtc'

# %% [markdown]
# I had to provide random numbers to the atoms and then include the sugars in the same resid as the rest of the lipid. I then made the simulation while with -pbc nojump, after which I wrote out every resid individually, and then cat them together again, such that I could use the pdb of just resid 1.

# %% [markdown]
# ### Manual stuff : you will need to make the mapping and define bonds and angles. The optimization of the bonded parameters you can do iteratively

# %%
os.chdir(main_dir)

# %%
#Load atomistic universe
u = md.Universe(GRO, XTC)

# %%
resname = np.unique(u.select_atoms('all and not resname TIP3 POPC and not name SOD CLA').resnames)[0]

# %%
sel = u.select_atoms('resname {} and resid 73'.format(resname))

# %%
ng.show_mdanalysis(sel)
# Out:
# NGLWidget(max_frame=10000)

# %%
#Make AA sims whole for later 
#os.system('echo 0 | gmx trjconv -s {} -f {} -pbc whole -o AA_whole.xtc'.format(TPR, XTC))

# %% [markdown]
# ### Define mapping

# %%
#Define manually
NOH = ['NF','HNF','C1F','OF'] #amide + carbonyl
OH  = ['C1S' , 'H1S', 'H1T', 'O1', 'HO1'] #The alcohol connecting to the sugar
GLA = ['C2F', 'H2F','O2', 'HO2', 'C3F', 'H3F','H3G'] # connected to the amide
GLB = ['C2S','H2S','C3S','C4S','H3S','O3','HO3','O4','HO4','H4S'] #two alcohols  

C1B = ['C5S','H5T','H5S','C6S','H6T','H6S','C7S','H7T','H7S','C8S','H8T','H8S','C9S','H9T','H9S']
C2B = ['C10S','H10T','H10S','C11S','H11T','H11S','C12S','H12T','H12S','C13S','H13T','H13S']
C1A = ['C5F','H5G','H5F','C6F','H6F','H6G','C7F','H7F','H7G','C8F','H8F','H8G','C9F','H9F','H9G']
C2A = ['C10F','H10F','H10G','C11F','H11F','H11G','C12F','H12F','H12G','C13F','H13F','H13G']

bead_assignments = [  NOH,   OH,     GLA,    GLB,  C1A,   C2A,   C1B,   C2B]
bead_types       = [ 'SP3d', 'TP1', 'SN4a',  'N4a', 'C1', 'C1',  'C1',  'C1']
bead_names       = [ 'NOH',  'OH',  'GLA',   'GLB', 'C1A', 'C2A', 'C1B', 'C2B']
bead_sizes       = [  'S' ,   'T',   'S',    'R'  ,  'R',   'R',   'R',   'R']
bead_charges     = [  0,      0,      0,       0,      0,     0,     0,     0]

# %%
flat_list = [item for sublist in bead_assignments for item in sublist]

# %%
all_AA_atoms = ' '.join('{}'.format(i) for i in flat_list)

# %%
selection_special = 'name {}'.format(all_AA_atoms)

# %%
selection_special
# Out:
# 'name NF HNF C1F OF C1S H1S H1T O1 HO1 C2F H2F O2 HO2 C3F H3F H3G C2S H2S C3S C4S H3S O3 HO3 O4 HO4 H4S C5F H5G H5F C6F H6F H6G C7F H7F H7G C8F H8F H8G C9F H9F H9G C10F H10F H10G C11F H11F H11G C12F H12F H12G C13F H13F H13G C5S H5T H5S C6S H6T H6S C7S H7T H7S C8S H8T H8S C9S H9T H9S C10S H10T H10S C11S H11T H11S C12S H12T H12S C13S H13T H13S'

# %% [markdown]
# ### Define angles, bonds, and possible dihedrals

# %%
#define manually
ang_tgts = [['C2A','C1A','GLA'],
            ['C1A','GLA','NOH'],
           ['GLB','NOH','OH'],
           ['NOH','OH','GLB'],
            ['OH','GLB','C1B'],
             ['OH','GLA','C1A'],
            ['GLB','C1B','C2B'],
            ['GLA','NOH','GLB'],
           ]

dist_tgts = [['C1B','C2B'],
            ['C1A','GLA'],
            ['GLA','NOH'],
            ['NOH','OH'],
             ['OH','GLB'],
            ['NOH','GLB'],
             ['GLB','C1B'],
             ['C1A','C2A']]

dihed_tgts = [['GLA','NOH','OH','GLB'],
             ['GLA','NOH','GLB','C1B'],
             ['GLB','NOH','GLA','C1A'],
             ['NOH','OH','GLB','C1B'],]

#D_ang, D_bond = make_angle_bond_dicts(ang_tgts, dist_tgts, bead_names)
D_dihed, D_ang, D_bond = make_angle_bond_dihed_dicts(ang_tgts, dist_tgts, dihed_tgts, bead_names)

bins_dihed = np.arange(-181,181,2)
bins_angl = np.arange(-1,181,2)
bins_dist = np.arange(0,15,0.2)

bins_dihed_x = (bins_dihed[1:] + bins_dihed[:-1]) / 2
bins_angl_x = (bins_angl[1:] + bins_angl[:-1]) / 2
bins_dist_x = (bins_dist[1:] + bins_dist[:-1]) / 2


List_angles = [[0],[1],[2],[3],[4],[5],[6],[7]]

List_bonds =[[0],[1],[2],[3],[4],[5],[6],[7]]

List_dihed = [[0],[1],[2],[3]]

# %% [markdown]
# ## map from aa to cg

# %%
map_aa2cg(u, resname, bead_assignments, bead_names, bead_sizes, 'AA_whole.xtc', GRO)
# Out:
#                        :-) GROMACS - gmx traj, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2
# Command line:
#   gmx traj -f CER6_POPC.gro -s all_hydrogen.gro -n index.ndx -com -ng 64 -oxt cg.gro
#
# Group     0 (  mdanalysis001) has     4 elements
# Group     1 (  mdanalysis002) has     5 elements
# Group     2 (  mdanalysis003) has     7 elements
# Group     3 (  mdanalysis004) has    10 elements
# Group     4 (  mdanalysis005) has    15 elements
# Group     5 (  mdanalysis006) has    12 elements
# Group     6 (  mdanalysis007) has    15 elements
# Group     7 (  mdanalysis008) has    12 elements
# Group     8 (  mdanalysis009) has     4 elements
# Group     9 (  mdanalysis010) has     5 elements
# Group    10 (  mdanalysis011) has     7 elements
# Group    11 (  mdanalysis012) has    10 elements
# Group    12 (  mdanalysis013) has    15 elements
# Group    13 (  mdanalysis014) has    12 elements
# Group    14 (  mdanalysis015) has    15 elements
# Group    15 (  mdanalysis016) has    12 elements
# Group    16 (  mdanalysis017) has     4 elements
# Group    17 (  mdanalysis018) has     5 elements
# Group    18 (  mdanalysis019) has     7 elements
# Group    19 (  mdanalysis020) has    10 elements
# Group    20 (  mdanalysis021) has    15 elements
# Group    21 (  mdanalysis022) has    12 elements
# Group    22 (  mdanalysis023) has    15 elements
# Group    23 (  mdanalysis024) has    12 elements
# Group    24 (  mdanalysis025) has     4 elements
# Group    25 (  mdanalysis026) has     5 elements
# Group    26 (  mdanalysis027) has     7 elements
# Group    27 (  mdanalysis028) has    10 elements
# Group    28 (  mdanalysis029) has    15 elements
# Group    29 (  mdanalysis030) has    12 elements
# Group    30 (  mdanalysis031) has    15 elements
# Group    31 (  mdanalysis032) has    12 elements
# Group    32 (  mdanalysis033) has     4 elements
# Group    33 (  mdanalysis034) has     5 elements
# Group    34 (  mdanalysis035) has     7 elements
# Group    35 (  mdanalysis036) has    10 elements
# Group    36 (  mdanalysis037) has    15 elements
# Group    37 (  mdanalysis038) has    12 elements
# Group    38 (  mdanalysis039) has    15 elements
# Group    39 (  mdanalysis040) has    12 elements
# Group    40 (  mdanalysis041) has     4 elements
# Group    41 (  mdanalysis042) has     5 elements
# Group    42 (  mdanalysis043) has     7 elements
# Group    43 (  mdanalysis044) has    10 elements
# Group    44 (  mdanalysis045) has    15 elements
# Group    45 (  mdanalysis046) has    12 elements
# Group    46 (  mdanalysis047) has    15 elements
# Group    47 (  mdanalysis048) has    12 elements
# Group    48 (  mdanalysis049) has     4 elements
# Group    49 (  mdanalysis050) has     5 elements
# Group    50 (  mdanalysis051) has     7 elements
# Group    51 (  mdanalysis052) has    10 elements
# Group    52 (  mdanalysis053) has    15 elements
# Group    53 (  mdanalysis054) has    12 elements
# Group    54 (  mdanalysis055) has    15 elements
# Group    55 (  mdanalysis056) has    12 elements
# Group    56 (  mdanalysis057) has     4 elements
# Group    57 (  mdanalysis058) has     5 elements
# Group    58 (  mdanalysis059) has     7 elements
# Group    59 (  mdanalysis060) has    10 elements
# Group    60 (  mdanalysis061) has    15 elements
# Group    61 (  mdanalysis062) has    12 elements
# Group    62 (  mdanalysis063) has    15 elements
# Group    63 (  mdanalysis064) has    12 elements
# Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group:
# Back Off! I just backed up cg.gro to ./#cg.gro.4#
# Reading frames from gro file 'Title', 21087 atoms.
# Reading frame       0 time    0.000
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Last frame          0 time    0.000
#
# GROMACS reminds you: "This is where we have been working hard to push down performance." (Szilard Pall, GTC 2015 talk)
#
#                        :-) GROMACS - gmx traj, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2
# Command line:
#   gmx traj -f AA_whole.xtc -s all_hydrogen.gro -n index.ndx -com -ng 64 -oxt cg.xtc
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# Selected 0: 'mdanalysis001'
# Selected 1: 'mdanalysis002'
# Selected 2: 'mdanalysis003'
# Selected 3: 'mdanalysis004'
# Selected 4: 'mdanalysis005'
# Selected 5: 'mdanalysis006'
# Selected 6: 'mdanalysis007'
# Selected 7: 'mdanalysis008'
# Selected 8: 'mdanalysis009'
# Selected 9: 'mdanalysis010'
# Selected 10: 'mdanalysis011'
# Selected 11: 'mdanalysis012'
# Selected 12: 'mdanalysis013'
# Selected 13: 'mdanalysis014'
# Selected 14: 'mdanalysis015'
# Selected 15: 'mdanalysis016'
# Selected 16: 'mdanalysis017'
# Selected 17: 'mdanalysis018'
# Selected 18: 'mdanalysis019'
# Selected 19: 'mdanalysis020'
# Selected 20: 'mdanalysis021'
# Selected 21: 'mdanalysis022'
# Selected 22: 'mdanalysis023'
# Selected 23: 'mdanalysis024'
# Selected 24: 'mdanalysis025'
# Selected 25: 'mdanalysis026'
# Selected 26: 'mdanalysis027'
# Selected 27: 'mdanalysis028'
# Selected 28: 'mdanalysis029'
# Selected 29: 'mdanalysis030'
# Selected 30: 'mdanalysis031'
# Selected 31: 'mdanalysis032'
# Selected 32: 'mdanalysis033'
# Selected 33: 'mdanalysis034'
# Selected 34: 'mdanalysis035'
# Selected 35: 'mdanalysis036'
# Selected 36: 'mdanalysis037'
# Selected 37: 'mdanalysis038'
# Selected 38: 'mdanalysis039'
# Selected 39: 'mdanalysis040'
# Selected 40: 'mdanalysis041'
# Selected 41: 'mdanalysis042'
# Selected 42: 'mdanalysis043'
# Selected 43: 'mdanalysis044'
# Selected 44: 'mdanalysis045'
# Selected 45: 'mdanalysis046'
# Selected 46: 'mdanalysis047'
# Selected 47: 'mdanalysis048'
# Selected 48: 'mdanalysis049'
# Selected 49: 'mdanalysis050'
# Selected 50: 'mdanalysis051'
# Selected 51: 'mdanalysis052'
# Selected 52: 'mdanalysis053'
# Selected 53: 'mdanalysis054'
# Selected 54: 'mdanalysis055'
# Selected 55: 'mdanalysis056'
# Selected 56: 'mdanalysis057'
# Selected 57: 'mdanalysis058'
# Selected 58: 'mdanalysis059'
# Selected 59: 'mdanalysis060'
# Selected 60: 'mdanalysis061'
# Selected 61: 'mdanalysis062'
# Selected 62: 'mdanalysis063'
# Selected 63: 'mdanalysis064'
# Group     0 (  mdanalysis001) has     4 elements
# Group     1 (  mdanalysis002) has     5 elements
# Group     2 (  mdanalysis003) has     7 elements
# Group     3 (  mdanalysis004) has    10 elements
# Group     4 (  mdanalysis005) has    15 elements
# Group     5 (  mdanalysis006) has    12 elements
# Group     6 (  mdanalysis007) has    15 elements
# Group     7 (  mdanalysis008) has    12 elements
# Group     8 (  mdanalysis009) has     4 elements
# Group     9 (  mdanalysis010) has     5 elements
# Group    10 (  mdanalysis011) has     7 elements
# Group    11 (  mdanalysis012) has    10 elements
# Group    12 (  mdanalysis013) has    15 elements
# Group    13 (  mdanalysis014) has    12 elements
# Group    14 (  mdanalysis015) has    15 elements
# Group    15 (  mdanalysis016) has    12 elements
# Group    16 (  mdanalysis017) has     4 elements
# Group    17 (  mdanalysis018) has     5 elements
# Group    18 (  mdanalysis019) has     7 elements
# Group    19 (  mdanalysis020) has    10 elements
# Group    20 (  mdanalysis021) has    15 elements
# Group    21 (  mdanalysis022) has    12 elements
# Group    22 (  mdanalysis023) has    15 elements
# Group    23 (  mdanalysis024) has    12 elements
# Group    24 (  mdanalysis025) has     4 elements
# Group    25 (  mdanalysis026) has     5 elements
# Group    26 (  mdanalysis027) has     7 elements
# Group    27 (  mdanalysis028) has    10 elements
# Group    28 (  mdanalysis029) has    15 elements
# Group    29 (  mdanalysis030) has    12 elements
# Group    30 (  mdanalysis031) has    15 elements
# Group    31 (  mdanalysis032) has    12 elements
# Group    32 (  mdanalysis033) has     4 elements
# Group    33 (  mdanalysis034) has     5 elements
# Group    34 (  mdanalysis035) has     7 elements
# Group    35 (  mdanalysis036) has    10 elements
# Group    36 (  mdanalysis037) has    15 elements
# Group    37 (  mdanalysis038) has    12 elements
# Group    38 (  mdanalysis039) has    15 elements
# Group    39 (  mdanalysis040) has    12 elements
# Group    40 (  mdanalysis041) has     4 elements
# Group    41 (  mdanalysis042) has     5 elements
# Group    42 (  mdanalysis043) has     7 elements
# Group    43 (  mdanalysis044) has    10 elements
# Group    44 (  mdanalysis045) has    15 elements
# Group    45 (  mdanalysis046) has    12 elements
# Group    46 (  mdanalysis047) has    15 elements
# Group    47 (  mdanalysis048) has    12 elements
# Group    48 (  mdanalysis049) has     4 elements
# Group    49 (  mdanalysis050) has     5 elements
# Group    50 (  mdanalysis051) has     7 elements
# Group    51 (  mdanalysis052) has    10 elements
# Group    52 (  mdanalysis053) has    15 elements
# Group    53 (  mdanalysis054) has    12 elements
# Group    54 (  mdanalysis055) has    15 elements
# Group    55 (  mdanalysis056) has    12 elements
# Group    56 (  mdanalysis057) has     4 elements
# Group    57 (  mdanalysis058) has     5 elements
# Group    58 (  mdanalysis059) has     7 elements
# Group    59 (  mdanalysis060) has    10 elements
# Group    60 (  mdanalysis061) has    15 elements
# Group    61 (  mdanalysis062) has    12 elements
# Group    62 (  mdanalysis063) has    15 elements
# Group    63 (  mdanalysis064) has    12 elements
# Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group: Select a group:
# Back Off! I just backed up cg.xtc to ./#cg.xtc.4#
# Reading frame       0 time    0.000
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Reading frame    9000 time 900000.000
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# Selected 0: 'mdanalysis001'
# Selected 1: 'mdanalysis002'
# Selected 2: 'mdanalysis003'
# Selected 3: 'mdanalysis004'
# Selected 4: 'mdanalysis005'
# Selected 5: 'mdanalysis006'
# Selected 6: 'mdanalysis007'
# Selected 7: 'mdanalysis008'
# Selected 8: 'mdanalysis009'
# Selected 9: 'mdanalysis010'
# Selected 10: 'mdanalysis011'
# Selected 11: 'mdanalysis012'
# Selected 12: 'mdanalysis013'
# Selected 13: 'mdanalysis014'
# Selected 14: 'mdanalysis015'
# Selected 15: 'mdanalysis016'
# Selected 16: 'mdanalysis017'
# Selected 17: 'mdanalysis018'
# Selected 18: 'mdanalysis019'
# Selected 19: 'mdanalysis020'
# Selected 20: 'mdanalysis021'
# Selected 21: 'mdanalysis022'
# Selected 22: 'mdanalysis023'
# Selected 23: 'mdanalysis024'
# Selected 24: 'mdanalysis025'
# Selected 25: 'mdanalysis026'
# Selected 26: 'mdanalysis027'
# Selected 27: 'mdanalysis028'
# Selected 28: 'mdanalysis029'
# Selected 29: 'mdanalysis030'
# Selected 30: 'mdanalysis031'
# Selected 31: 'mdanalysis032'
# Selected 32: 'mdanalysis033'
# Selected 33: 'mdanalysis034'
# Selected 34: 'mdanalysis035'
# Selected 35: 'mdanalysis036'
# Selected 36: 'mdanalysis037'
# Selected 37: 'mdanalysis038'
# Selected 38: 'mdanalysis039'
# Selected 39: 'mdanalysis040'
# Selected 40: 'mdanalysis041'
# Selected 41: 'mdanalysis042'
# Selected 42: 'mdanalysis043'
# Selected 43: 'mdanalysis044'
# Selected 44: 'mdanalysis045'
# Selected 45: 'mdanalysis046'
# Selected 46: 'mdanalysis047'
# Selected 47: 'mdanalysis048'
# Selected 48: 'mdanalysis049'
# Selected 49: 'mdanalysis050'
# Selected 50: 'mdanalysis051'
# Selected 51: 'mdanalysis052'
# Selected 52: 'mdanalysis053'
# Selected 53: 'mdanalysis054'
# Selected 54: 'mdanalysis055'
# Selected 55: 'mdanalysis056'
# Selected 56: 'mdanalysis057'
# Selected 57: 'mdanalysis058'
# Selected 58: 'mdanalysis059'
# Selected 59: 'mdanalysis060'
# Selected 60: 'mdanalysis061'
# Selected 61: 'mdanalysis062'
# Selected 62: 'mdanalysis063'
# Selected 63: 'mdanalysis064'
# Last frame      10000 time 1000000.000
#
# GROMACS reminds you: "When you get right down to it, almost every explanation Man came up with for anything until about 1926 was stupid." (Dave Barry)

# %% [markdown]
# ### initial SASA

# %%
CG  = ['cg_good.gro', #GRO
       'cg.xtc']      #XTC
AA = [GRO,XTC]

# %%
os.chdir(main_dir)
run_SASA('CG', CG, resname, main_dir, bead_names, bead_sizes)
# Out:
# /home/ltr/anaconda3/envs/jupyter_env/lib/python3.10/site-packages/MDAnalysis/coordinates/XDR.py:240: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn("Reload offsets from trajectory\n "
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG
# Command line:
#   gmx sasa -f ../cg.xtc -s ../cg_good.gro -n /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/index.ndx -ndots 4800 -probe 0.191 -or /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/resarea_SASA.xvg -o /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/SASA.xvg
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
# Reading frame       0 time    0.000
# Back Off! I just backed up /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/SASA.xvg to /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/#SASA.xvg.3#
# Reading frame      30 time 3000.000
# entering /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
# Reading frame    9000 time 900000.000
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
# Last frame      10000 time 1000000.000
#
# Back Off! I just backed up /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/resarea_SASA.xvg to /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG/#resarea_SASA.xvg.3#
# Analyzed 10001 frames, last time 1000000.000
#
# GROMACS reminds you: "Bad As This Shit Is, This Shit Ain't As Bad As You Think It Is." (Jackie Brown)
#
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG
# Command line:
#   gmx sasa -s gro.gro -o temp.xvg -probe 0.191 -ndots 240 -q surface.pdb
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
#
# Back Off! I just backed up temp.xvg to ./#temp.xvg.3#
#
# Back Off! I just backed up surface.pdb to ./#surface.pdb.3#
# Analyzed topology coordinates
#
# GROMACS reminds you: "Bad As This Shit Is, This Shit Ain't As Bad As You Think It Is." (Jackie Brown)

# %%
os.chdir(main_dir)
run_SASA('AA', AA, resname, main_dir, bead_names, bead_sizes, selection=selection_special)
#Im only mapping the sugars and linker, so Im only doing the SASA calculation of the beads Im mapping for comparison.
# Out:
# cp: cannot stat '/data1/lisbeth/Params/Pzifer_alcoholamine/7_SASA_longer_bonds/vdwradii_AllAtom_rowland.dat': No such file or directory
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA
# Command line:
#   gmx sasa -f ../CER6_POPC.xtc -s ../CER6_POPC.gro -n /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/index.ndx -ndots 4800 -probe 0.191 -or /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/resarea_SASA.xvg -o /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/SASA.xvg
# entering /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
# Reading frame       0 time    0.000
# Back Off! I just backed up /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/SASA.xvg to /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/#SASA.xvg.3#
# Reading frame       7 time  700.000
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
# Reading frame    9000 time 900000.000
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
# Last frame      10000 time 1000000.000
#
# Back Off! I just backed up /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/resarea_SASA.xvg to /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA/#resarea_SASA.xvg.3#
# Analyzed 10001 frames, last time 1000000.000
#
# GROMACS reminds you: "The last good thing written in C was Franz Schubert's Symphony Number 9." (Erwin Dieterich)
#
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/AA
# Command line:
#   gmx sasa -s gro.gro -o temp.xvg -probe 0.191 -ndots 240 -q surface.pdb
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
#
# Back Off! I just backed up temp.xvg to ./#temp.xvg.3#
#
# Back Off! I just backed up surface.pdb to ./#surface.pdb.3#
# Analyzed topology coordinates
#
# GROMACS reminds you: "The last good thing written in C was Franz Schubert's Symphony Number 9." (Erwin Dieterich)

# %%
CG_xvg = '{}/CG/resarea_SASA.xvg'.format(main_dir)
AA_xvg = '{}/AA/resarea_SASA.xvg'.format(main_dir)

SASA_CG, SASA_AA =  plot_SASA(AA_xvg, CG_xvg, resname)
# Out:
# SASA AA: [10.246  0.666]
# SASA CG: [9.665 0.656]
# percent difference between the models.
# 5.670505563146611

# %% [markdown]
# ## CG in water w. 0.15 M NaCl

# %%
#os.mkdir('CG_WAT')
os.chdir('{}/CG_WAT'.format(main_dir))
#os.system('cp ../cg_good.gro .')

# %% [markdown]
# ### write an initial itp CG

# %%
# # #Write an initial CG itp file. You will of course need to set bond lengt, angles and so forth, but the rest is there
# write_initial_CGitp2(resname,
#     bead_names,
#     bead_sizes,
#     bead_types,
#     bead_charges,
#     D_bond,
#     D_ang,
#     D_dihed,
#     dist_tgts,
#     ang_tgts,
#     dihed_tgts)

# %%
# !rm *tpr
# Out:
# rm: cannot remove '*tpr': No such file or directory

# %% [markdown]
# #### Setup sydtem and run for a small period of time

# %%
mdp_loc
# Out:
# '/mnt/f/AA_SIMS_WATER_IONS/MDPs'

# %%
prepare_setup_water(mdp_loc)
#re_run(resname, mdp_loc, maxwarn=5)
## Removed the dihedral section from the itp
# Out:
#                      :-) GROMACS - gmx editconf, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx editconf -f res.gro -o box.gro -box 5 5 5 -bt cubic
#
#
# Back Off! I just backed up box.gro to ./#box.gro.1#
#
# GROMACS reminds you: "Above all, don't fear difficult moments. The best comes from them." (Rita Levi-Montalcini)
#
#                      :-) GROMACS - gmx solvate, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx solvate -cp box.gro -cs /mnt/f/AA_SIMS_WATER_IONS/MDPs/water.gro -o watered.gro -p topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# Generating solvent configuration
# Will generate new solvent configuration of 1x1x1 boxes
# Solvent box contains 1260 atoms in 1260 residues
# Removed 66 solvent atoms due to solvent-solvent overlap
# Removed 1 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#       W (   1 atoms):  1193 residues
# Generated solvent containing 1193 atoms in 1193 residues
# Writing generated configuration to watered.gro
#
# Back Off! I just backed up watered.gro to ./#watered.gro.1#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 8 atoms
# Volume: 202.862 nm^3, corresponds to roughly 91200 electrons
# No velocities found
#     system size :  0.963  0.954  0.840 (nm)
#     diameter    :  1.241               (nm)
#     center      :  3.049  1.412  4.854 (nm)
#     box vectors :  5.082  5.082  7.855 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 202.86               (nm^3)
#     shift       : -0.549  1.088 -2.354 (nm)
# new center      :  2.500  2.500  2.500 (nm)
# new box vectors :  5.000  5.000  5.000 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  : 125.00               (nm^3)
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
# Output configuration contains 1201 atoms in 1194 residues
# Volume                 :         125 (nm^3)
# Density                :      2914.9 (g/l)
# Number of solvent molecules:   1193
#
# Processing topology
#
# Back Off! I just backed up topol.top to ./#topol.top.1#
#
# GROMACS reminds you: "Above all, don't fear difficult moments. The best comes from them." (Rita Levi-Montalcini)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx grompp -f /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp -c watered.gro -p topol.top -o memion.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'cpp'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'unconstrained_start' by 'continuation'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
#
# NOTE 1 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   You have set rlist larger than the interaction cut-off, but you also have
#   verlet-buffer-tolerance > 0. Will set rlist using
#   verlet-buffer-tolerance.
#
#
# NOTE 2 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, consider
#   setting nstcomm equal to nstcalcenergy for less overhead
# Adding line for 1193 solvent molecules with resname (W) to topology file (topol.top)
# Number of degrees of freedom in T-Coupling group System is 3600.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 3 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   COM removal frequency is set to (1).
#   Other settings require a global communication frequency of 100.
#   Note that this will require additional global communication steps,
#   which will reduce performance when using multiple ranks.
#   Consider setting nstcomm to a multiple of 100.
#
#
# There were 3 NOTEs
#
# GROMACS reminds you: "Life in the streets is not easy" (Marky Mark)
#
#                       :-) GROMACS - gmx genion, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx genion -s memion.tpr -o memion.gro -p topol.top -pname NA -pq +1 -nname CL -nq -1 -neutral
#
# Reading file memion.tpr, VERSION 2023.1 (single precision)
# Reading file memion.tpr, VERSION 2023.1 (single precision)
# No ions to add, will just copy input configuration.
#
# Back Off! I just backed up memion.gro to ./#memion.gro.1#
#
# GROMACS reminds you: "Life in the streets is not easy" (Marky Mark)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx grompp -f /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp -c memion.gro -p topol.top -o memion_2.tpr -maxwarn 4
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'cpp'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'unconstrained_start' by 'continuation'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
#
# NOTE 1 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   You have set rlist larger than the interaction cut-off, but you also have
#   verlet-buffer-tolerance > 0. Will set rlist using
#   verlet-buffer-tolerance.
#
#
# NOTE 2 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, consider
#   setting nstcomm equal to nstcalcenergy for less overhead
# Setting the LD random seed to 1877934047
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'W'
# Analysing residue names:
# There are:  1194      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 25 Mb of data
# Number of degrees of freedom in T-Coupling group System is 3600.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 3 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   COM removal frequency is set to (1).
#   Other settings require a global communication frequency of 100.
#   Note that this will require additional global communication steps,
#   which will reduce performance when using multiple ranks.
#   Consider setting nstcomm to a multiple of 100.
#
#
# There were 3 NOTEs
#
# GROMACS reminds you: "In my opinion, we don't devote nearly enough scientific research to finding a cure for jerks." (Bill Watterson)
#
#                       :-) GROMACS - gmx genion, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx genion -s memion_2.tpr -o memion_2.gro -p topol.top -pname NA -pq +1 -nname CL -nq -1 -np 4 -nn 4
#
# Reading file memion_2.tpr, VERSION 2023.1 (single precision)
# Reading file memion_2.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  1201 elements
# Group     1 (          Other) has  1201 elements
# Group     2 (           CER6) has     8 elements
# Group     3 (              W) has  1193 elements
# Select a group: Number of (1-atomic) solvent molecules: 1193
#
# Back Off! I just backed up topol.top to ./#topol.top.2#
# Using random seed -1075970103.
# Replacing solvent molecule 229 (atom 237) with NA
# Replacing solvent molecule 949 (atom 957) with NA
# Replacing solvent molecule 929 (atom 937) with NA
# Replacing solvent molecule 1032 (atom 1040) with NA
# Replacing solvent molecule 233 (atom 241) with CL
# Replacing solvent molecule 670 (atom 678) with CL
# Replacing solvent molecule 205 (atom 213) with CL
# Replacing solvent molecule 317 (atom 325) with CL
#
#
# Back Off! I just backed up memion_2.gro to ./#memion_2.gro.1#
#
# GROMACS reminds you: "In my opinion, we don't devote nearly enough scientific research to finding a cure for jerks." (Bill Watterson)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx grompp -f /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp -c memion_2.gro -p topol.top -o m.tpr -maxwarn 5
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'cpp'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'unconstrained_start' by 'continuation'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
#
# NOTE 1 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   You have set rlist larger than the interaction cut-off, but you also have
#   verlet-buffer-tolerance > 0. Will set rlist using
#   verlet-buffer-tolerance.
#
#
# NOTE 2 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, consider
#   setting nstcomm equal to nstcalcenergy for less overhead
# Setting the LD random seed to -691142677
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'W'
# Analysing residue names:
# There are:  1194      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 25 Mb of data
# Will try to add 4 NA ions and 4 CL ions.
# Select a continuous group of solvent molecules
# Selected 3: 'W'
#
# Processing topology
# Replacing 8 solute molecules in topology file (topol.top)  by 4 NA and 4 CL ions.
# Number of degrees of freedom in T-Coupling group System is 3600.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 3 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/min.mdp]:
#   COM removal frequency is set to (1).
#   Other settings require a global communication frequency of 100.
#   Note that this will require additional global communication steps,
#   which will reduce performance when using multiple ranks.
#   Consider setting nstcomm to a multiple of 100.
#
#
# There were 3 NOTEs
#
# GROMACS reminds you: "X-rays will prove to be a hoax." (Lord Kelvin, while president of the Royal Society)
#
#                       :-) GROMACS - gmx mdrun, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx mdrun -v -deffnm m
#
#
# Back Off! I just backed up m.log to ./#m.log.1#
# Reading file m.tpr, VERSION 2023.1 (single precision)
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Back Off! I just backed up m.trr to ./#m.trr.1#
#
# Back Off! I just backed up m.edr to ./#m.edr.1#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =      1000000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  7.18624e+06 Fmax= 1.66869e+07, atom= 1162
# Step=    1, Dmax= 1.0e-02 nm, Epot=  4.90966e+06 Fmax= 7.12874e+06, atom= 612
# Step=    2, Dmax= 1.2e-02 nm, Epot=  3.18891e+06 Fmax= 3.47632e+06, atom= 993
# Step=    3, Dmax= 1.4e-02 nm, Epot=  2.09697e+06 Fmax= 1.36216e+06, atom= 993
# Step=    4, Dmax= 1.7e-02 nm, Epot=  1.28213e+06 Fmax= 5.47568e+05, atom= 29
# Step=    5, Dmax= 2.1e-02 nm, Epot=  7.80630e+05 Fmax= 2.98949e+05, atom= 68
# Step=    6, Dmax= 2.5e-02 nm, Epot=  5.07040e+05 Fmax= 1.68313e+05, atom= 68
# Step=    7, Dmax= 3.0e-02 nm, Epot=  3.15601e+05 Fmax= 1.51053e+05, atom= 215
# Step=    8, Dmax= 3.6e-02 nm, Epot=  2.26349e+05 Fmax= 2.51446e+05, atom= 540
# Step=    9, Dmax= 4.3e-02 nm, Epot=  1.89764e+05 Fmax= 2.16496e+05, atom= 797
# Step=   10, Dmax= 5.2e-02 nm, Epot=  1.55185e+05 Fmax= 1.88848e+05, atom= 574
# Step=   11, Dmax= 6.2e-02 nm, Epot=  1.28789e+05 Fmax= 2.40263e+05, atom= 574
# Step=   12, Dmax= 7.4e-02 nm, Epot=  1.07301e+05 Fmax= 1.13792e+05, atom= 574
# Step=   13, Dmax= 8.9e-02 nm, Epot=  7.98866e+04 Fmax= 3.14959e+05, atom= 543
# Step=   14, Dmax= 1.1e-01 nm, Epot=  7.23735e+04 Fmax= 3.40681e+05, atom= 934
# Step=   16, Dmax= 6.4e-02 nm, Epot=  6.35221e+04 Fmax= 1.57057e+05, atom= 797
# Step=   17, Dmax= 7.7e-02 nm, Epot=  5.57862e+04 Fmax= 1.24406e+05, atom= 540
# Step=   18, Dmax= 9.2e-02 nm, Epot=  4.44313e+04 Fmax= 5.83504e+04, atom= 702
# Step=   19, Dmax= 1.1e-01 nm, Epot=  3.51808e+04 Fmax= 3.33346e+05, atom= 540
# Step=   20, Dmax= 1.3e-01 nm, Epot=  2.54331e+04 Fmax= 3.45692e+04, atom= 540
# Step=   21, Dmax= 1.6e-01 nm, Epot=  9.78747e+03 Fmax= 5.19342e+04, atom= 287
# Step=   23, Dmax= 9.6e-02 nm, Epot=  5.01318e+03 Fmax= 2.01646e+04, atom= 335
# Step=   24, Dmax= 1.2e-01 nm, Epot= -2.82943e+03 Fmax= 1.78498e+04, atom= 797
# Step=   25, Dmax= 1.4e-01 nm, Epot= -8.49797e+03 Fmax= 8.48412e+03, atom= 797
# Step=   26, Dmax= 1.7e-01 nm, Epot= -1.45224e+04 Fmax= 1.52260e+04, atom= 540
# Setting the LD random seed to -8415235
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
# Analysing residue names:
# There are:  1194      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 25 Mb of data
# Step=   28, Dmax= 9.9e-02 nm, Epot= -1.70157e+04 Fmax= 6.64190e+03, atom= 851
# Step=   29, Dmax= 1.2e-01 nm, Epot= -1.93649e+04 Fmax= 5.63570e+03, atom= 851
# Step=   31, Dmax= 7.2e-02 nm, Epot= -2.08263e+04 Fmax= 7.61276e+03, atom= 2658
# Step=   32, Dmax= 8.6e-02 nm, Epot= -2.17039e+04 Fmax= 1.11619e+04, atom= 944
# Step=   33, Dmax= 1.0e-01 nm, Epot= -2.25068e+04 Fmax= 7.56223e+03, atom= 935
# Step=   34, Dmax= 1.2e-01 nm, Epot= -2.27614e+04 Fmax= 2.34069e+04, atom= 935
# Step=   35, Dmax= 1.5e-01 nm, Epot= -2.40819e+04 Fmax= 4.18235e+03, atom= 278
# Step=   36, Dmax= 1.8e-01 nm, Epot= -2.45476e+04 Fmax= 2.59312e+04, atom= 1192
# Step=   37, Dmax= 2.1e-01 nm, Epot= -2.50067e+04 Fmax= 2.51815e+04, atom= 317
# Step=   39, Dmax= 1.3e-01 nm, Epot= -2.61699e+04 Fmax= 2.43273e+03, atom= 3176
# Step=   40, Dmax= 1.5e-01 nm, Epot= -2.72812e+04 Fmax= 5.62291e+03, atom= 699
# Step=   42, Dmax= 9.2e-02 nm, Epot= -2.79294e+04 Fmax= 3.24410e+03, atom= 719
# Step=   43, Dmax= 1.1e-01 nm, Epot= -2.84886e+04 Fmax= 2.71101e+03, atom= 1036
# Step=   44, Dmax= 1.3e-01 nm, Epot= -2.90707e+04 Fmax= 2.32768e+03, atom= 670
# Step=   45, Dmax= 1.6e-01 nm, Epot= -2.93376e+04 Fmax= 4.18191e+03, atom= 670
# Step=   47, Dmax= 9.6e-02 nm, Epot= -2.99513e+04 Fmax= 1.75622e+03, atom= 978
# Step=   49, Dmax= 5.7e-02 nm, Epot= -3.02474e+04 Fmax= 1.49474e+03, atom= 978
# Step=   50, Dmax= 6.9e-02 nm, Epot= -3.04116e+04 Fmax= 5.08742e+03, atom= 978
# Step=   51, Dmax= 8.3e-02 nm, Epot= -3.06767e+04 Fmax= 1.19867e+03, atom= 978
# Step=   52, Dmax= 9.9e-02 nm, Epot= -3.08275e+04 Fmax= 8.97340e+03, atom= 978
# Step=   53, Dmax= 1.2e-01 nm, Epot= -3.11485e+04 Fmax= 1.38039e+03, atom= 978
# Step=   55, Dmax= 7.1e-02 nm, Epot= -3.13886e+04 Fmax= 1.49534e+03, atom= 597
# Step=   56, Dmax= 8.6e-02 nm, Epot= -3.14673e+04 Fmax= 3.40051e+03, atom= 597
# Step=   57, Dmax= 1.0e-01 nm, Epot= -3.16643e+04 Fmax= 1.79989e+03, atom= 597
# Step=   59, Dmax= 6.2e-02 nm, Epot= -3.18670e+04 Fmax= 8.18956e+02, atom= 978
# Step=   60, Dmax= 7.4e-02 nm, Epot= -3.19947e+04 Fmax= 2.45132e+03, atom= 978
# Step=   61, Dmax= 8.9e-02 nm, Epot= -3.20844e+04 Fmax= 2.24113e+03, atom= 597
# Step=   63, Dmax= 5.3e-02 nm, Epot= -3.23215e+04 Fmax= 4.97184e+02, atom= 705
# Step=   65, Dmax= 3.2e-02 nm, Epot= -3.24445e+04 Fmax= 1.79375e+03, atom= 705
# Step=   66, Dmax= 3.8e-02 nm, Epot= -3.25442e+04 Fmax= 5.80010e+02, atom= 705
# Step=   67, Dmax= 4.6e-02 nm, Epot= -3.26446e+04 Fmax= 2.82824e+03, atom= 705
# Step=   68, Dmax= 5.5e-02 nm, Epot= -3.27447e+04 Fmax= 6.53737e+02, atom= 705
# Step=   69, Dmax= 6.6e-02 nm, Epot= -3.27488e+04 Fmax= 6.36001e+03, atom= 705
# Step=   70, Dmax= 8.0e-02 nm, Epot= -3.29449e+04 Fmax= 7.25190e+02, atom= 705
# Step=   72, Dmax= 4.8e-02 nm, Epot= -3.30656e+04 Fmax= 6.80240e+02, atom= 705
# Step=   73, Dmax= 5.7e-02 nm, Epot= -3.31129e+04 Fmax= 2.65549e+03, atom= 705
# Step=   74, Dmax= 6.9e-02 nm, Epot= -3.32108e+04 Fmax= 1.06571e+03, atom= 245
# Step=   75, Dmax= 8.3e-02 nm, Epot= -3.32436e+04 Fmax= 2.82064e+03, atom= 245
# Step=   76, Dmax= 9.9e-02 nm, Epot= -3.32640e+04 Fmax= 3.01804e+03, atom= 705
# Step=   77, Dmax= 1.2e-01 nm, Epot= -3.32719e+04 Fmax= 3.67297e+03, atom= 1200
# Step=   79, Dmax= 7.1e-02 nm, Epot= -3.33988e+04 Fmax= 1.32865e+03, atom= 265
# Step=   80, Dmax= 8.6e-02 nm, Epot= -3.34967e+04 Fmax= 1.26428e+03, atom= 1138
# Step=   81, Dmax= 1.0e-01 nm, Epot= -3.35204e+04 Fmax= 1.90319e+03, atom= 386
# Step=   83, Dmax= 6.2e-02 nm, Epot= -3.36233e+04 Fmax= 8.46557e+02, atom= 3930
# Step=   84, Dmax= 7.4e-02 nm, Epot= -3.36328e+04 Fmax= 2.41502e+03, atom= 1200
# Step=   85, Dmax= 8.9e-02 nm, Epot= -3.37087e+04 Fmax= 1.79076e+03, atom= 705
# Step=   87, Dmax= 5.3e-02 nm, Epot= -3.37875e+04 Fmax= 5.56706e+02, atom= 363
# Step=   88, Dmax= 6.4e-02 nm, Epot= -3.37956e+04 Fmax= 2.93092e+03, atom= 245
# Step=   89, Dmax= 7.7e-02 nm, Epot= -3.38955e+04 Fmax= 1.20782e+03, atom= 705
# Step=   90, Dmax= 9.2e-02 nm, Epot= -3.38971e+04 Fmax= 1.93553e+03, atom= 705
# Step=   92, Dmax= 5.5e-02 nm, Epot= -3.39995e+04 Fmax= 4.20351e+02, atom= 245
# Step=   93, Dmax= 6.6e-02 nm, Epot= -3.40656e+04 Fmax= 1.56776e+03, atom= 245
# Step=   94, Dmax= 7.9e-02 nm, Epot= -3.41075e+04 Fmax= 1.53950e+03, atom= 705
# Step=   96, Dmax= 4.8e-02 nm, Epot= -3.41691e+04 Fmax= 5.07117e+02, atom= 1200
# Step=   97, Dmax= 5.7e-02 nm, Epot= -3.42116e+04 Fmax= 1.21106e+03, atom= 1200
# Step=   98, Dmax= 6.9e-02 nm, Epot= -3.42408e+04 Fmax= 1.16873e+03, atom= 705
# Step=   99, Dmax= 8.2e-02 nm, Epot= -3.42631e+04 Fmax= 1.13792e+03, atom= 705
# Step=  101, Dmax= 4.9e-02 nm, Epot= -3.43258e+04 Fmax= 4.32672e+02, atom= 252
# Step=  102, Dmax= 5.9e-02 nm, Epot= -3.43337e+04 Fmax= 1.79984e+03, atom= 705
# Step=  103, Dmax= 7.1e-02 nm, Epot= -3.43906e+04 Fmax= 1.08958e+03, atom= 705
# Step=  104, Dmax= 8.5e-02 nm, Epot= -3.43934e+04 Fmax= 1.48485e+03, atom= 705
# Step=  106, Dmax= 5.1e-02 nm, Epot= -3.44638e+04 Fmax= 4.75148e+02, atom= 1200
# Step=  107, Dmax= 6.2e-02 nm, Epot= -3.44917e+04 Fmax= 1.30497e+03, atom= 1200
# Step=  108, Dmax= 7.4e-02 nm, Epot= -3.45140e+04 Fmax= 1.26542e+03, atom= 705
# Step=  109, Dmax= 8.9e-02 nm, Epot= -3.45140e+04 Fmax= 1.15137e+03, atom= 245
# Step=  111, Dmax= 5.3e-02 nm, Epot= -3.45796e+04 Fmax= 4.18083e+02, atom= 252
# Step=  113, Dmax= 3.2e-02 nm, Epot= -3.46116e+04 Fmax= 7.02050e+02, atom= 1195
# Step=  114, Dmax= 3.8e-02 nm, Epot= -3.46326e+04 Fmax= 7.20849e+02, atom= 1195
# Step=  115, Dmax= 4.6e-02 nm, Epot= -3.46495e+04 Fmax= 9.16043e+02, atom= 1195
# Step=  116, Dmax= 5.5e-02 nm, Epot= -3.46600e+04 Fmax= 9.71960e+02, atom= 1195
# Step=  117, Dmax= 6.6e-02 nm, Epot= -3.46607e+04 Fmax= 1.38526e+03, atom= 1195
# Step=  118, Dmax= 7.9e-02 nm, Epot= -3.46695e+04 Fmax= 1.23977e+03, atom= 964
# Step=  120, Dmax= 4.8e-02 nm, Epot= -3.47282e+04 Fmax= 3.85080e+02, atom= 986
# Step=  121, Dmax= 5.7e-02 nm, Epot= -3.47468e+04 Fmax= 8.85919e+02, atom= 1195
# Step=  123, Dmax= 3.4e-02 nm, Epot= -3.47854e+04 Fmax= 1.12902e+03, atom= 1195
# Step=  124, Dmax= 4.1e-02 nm, Epot= -3.48065e+04 Fmax= 4.41026e+02, atom= 964
# Step=  126, Dmax= 2.5e-02 nm, Epot= -3.48313e+04 Fmax= 1.78428e+02, atom= 1195
# Step=  127, Dmax= 3.0e-02 nm, Epot= -3.48513e+04 Fmax= 1.03070e+03, atom= 1195
# Step=  128, Dmax= 3.6e-02 nm, Epot= -3.48867e+04 Fmax= 3.35760e+02, atom= 1195
# Step=  129, Dmax= 4.3e-02 nm, Epot= -3.48894e+04 Fmax= 1.45918e+03, atom= 1195
# Step=  130, Dmax= 5.1e-02 nm, Epot= -3.49221e+04 Fmax= 4.12343e+02, atom= 1195
# Step=  132, Dmax= 3.1e-02 nm, Epot= -3.49465e+04 Fmax= 3.60222e+02, atom= 1195
# Step=  133, Dmax= 3.7e-02 nm, Epot= -3.49481e+04 Fmax= 1.30010e+03, atom= 1195
# Step=  134, Dmax= 4.4e-02 nm, Epot= -3.49770e+04 Fmax= 4.23931e+02, atom= 964
# Step=  136, Dmax= 2.7e-02 nm, Epot= -3.49999e+04 Fmax= 1.80344e+02, atom= 986
# Step=  137, Dmax= 3.2e-02 nm, Epot= -3.50093e+04 Fmax= 1.09958e+03, atom= 1195
# Step=  138, Dmax= 3.8e-02 nm, Epot= -3.50472e+04 Fmax= 4.42276e+02, atom= 1195
# Step=  140, Dmax= 2.3e-02 nm, Epot= -3.50612e+04 Fmax= 2.64755e+02, atom= 9645
# Step=  141, Dmax= 2.8e-02 nm, Epot= -3.50714e+04 Fmax= 9.80378e+02, atom= 1195
# Step=  142, Dmax= 3.3e-02 nm, Epot= -3.50897e+04 Fmax= 3.36462e+02, atom= 1195
# Step=  144, Dmax= 2.0e-02 nm, Epot= -3.51061e+04 Fmax= 1.95992e+02, atom= 1195
# Step=  145, Dmax= 2.4e-02 nm, Epot= -3.51217e+04 Fmax= 6.10552e+02, atom= 1195
# Step=  146, Dmax= 2.9e-02 nm, Epot= -3.51388e+04 Fmax= 3.83922e+02, atom= 1195
# Step=  147, Dmax= 3.4e-02 nm, Epot= -3.51440e+04 Fmax= 7.65504e+02, atom= 1195
# Step=  148, Dmax= 4.1e-02 nm, Epot= -3.51596e+04 Fmax= 5.72974e+02, atom= 1195
# Step=  150, Dmax= 2.5e-02 nm, Epot= -3.51775e+04 Fmax= 2.74852e+02, atom= 9645
# Step=  151, Dmax= 3.0e-02 nm, Epot= -3.51914e+04 Fmax= 7.48332e+02, atom= 964
# Step=  152, Dmax= 3.5e-02 nm, Epot= -3.51999e+04 Fmax= 5.16729e+02, atom= 1195
# Step=  153, Dmax= 4.3e-02 nm, Epot= -3.52035e+04 Fmax= 1.05894e+03, atom= 1195
# Step=  154, Dmax= 5.1e-02 nm, Epot= -3.52136e+04 Fmax= 6.07212e+02, atom= 964
# Step=  156, Dmax= 3.1e-02 nm, Epot= -3.52395e+04 Fmax= 2.10223e+02, atom= 497
# Step=  157, Dmax= 3.7e-02 nm, Epot= -3.52452e+04 Fmax= 1.15696e+03, atom= 497
# Step=  158, Dmax= 4.4e-02 nm, Epot= -3.52681e+04 Fmax= 7.49962e+02, atom= 1195
# Step=  160, Dmax= 2.6e-02 nm, Epot= -3.52834e+04 Fmax= 3.19365e+02, atom= 9645
# Step=  161, Dmax= 3.2e-02 nm, Epot= -3.52917e+04 Fmax= 8.06737e+02, atom= 964
# Step=  162, Dmax= 3.8e-02 nm, Epot= -3.53012e+04 Fmax= 4.64666e+02, atom= 1195
# Step=  164, Dmax= 2.3e-02 nm, Epot= -3.53178e+04 Fmax= 1.63382e+02, atom= 497
# Step=  165, Dmax= 2.7e-02 nm, Epot= -3.53275e+04 Fmax= 8.63222e+02, atom= 497
# Step=  166, Dmax= 3.3e-02 nm, Epot= -3.53462e+04 Fmax= 3.68050e+02, atom= 1195
# Step=  168, Dmax= 2.0e-02 nm, Epot= -3.53569e+04 Fmax= 2.34314e+02, atom= 9645
# Step=  169, Dmax= 2.4e-02 nm, Epot= -3.53638e+04 Fmax= 6.69829e+02, atom= 1195
# Step=  170, Dmax= 2.8e-02 nm, Epot= -3.53743e+04 Fmax= 3.30436e+02, atom= 1195
# Step=  172, Dmax= 1.7e-02 nm, Epot= -3.53858e+04 Fmax= 1.22814e+02, atom= 1195
# Step=  173, Dmax= 2.1e-02 nm, Epot= -3.53945e+04 Fmax= 6.51454e+02, atom= 1195
# Step=  174, Dmax= 2.5e-02 nm, Epot= -3.54125e+04 Fmax= 1.92432e+02, atom= 1195
# Step=  176, Dmax= 1.5e-02 nm, Epot= -3.54219e+04 Fmax= 2.33073e+02, atom= 1195
# Step=  177, Dmax= 1.8e-02 nm, Epot= -3.54292e+04 Fmax= 3.71263e+02, atom= 1195
# Step=  178, Dmax= 2.1e-02 nm, Epot= -3.54373e+04 Fmax= 2.92237e+02, atom= 1195
# Step=  179, Dmax= 2.6e-02 nm, Epot= -3.54411e+04 Fmax= 6.68552e+02, atom= 1195
# Step=  180, Dmax= 3.1e-02 nm, Epot= -3.54513e+04 Fmax= 3.47409e+02, atom= 964
# Step=  182, Dmax= 1.8e-02 nm, Epot= -3.54629e+04 Fmax= 1.25116e+02, atom= 1195
# Step=  183, Dmax= 2.2e-02 nm, Epot= -3.54666e+04 Fmax= 7.53634e+02, atom= 1195
# Step=  184, Dmax= 2.6e-02 nm, Epot= -3.54876e+04 Fmax= 1.69625e+02, atom= 1195
# Step=  186, Dmax= 1.6e-02 nm, Epot= -3.54966e+04 Fmax= 2.92691e+02, atom= 1195
# Step=  187, Dmax= 1.9e-02 nm, Epot= -3.55034e+04 Fmax= 3.22044e+02, atom= 1195
# Step=  188, Dmax= 2.3e-02 nm, Epot= -3.55096e+04 Fmax= 3.73755e+02, atom= 1195
# Step=  189, Dmax= 2.7e-02 nm, Epot= -3.55144e+04 Fmax= 5.50213e+02, atom= 1195
# Step=  190, Dmax= 3.3e-02 nm, Epot= -3.55204e+04 Fmax= 4.47200e+02, atom= 1195
# Step=  192, Dmax= 2.0e-02 nm, Epot= -3.55342e+04 Fmax= 1.35227e+02, atom= 9865
# Step=  193, Dmax= 2.4e-02 nm, Epot= -3.55439e+04 Fmax= 5.60251e+02, atom= 986
# Step=  194, Dmax= 2.8e-02 nm, Epot= -3.55528e+04 Fmax= 4.37646e+02, atom= 1195
# Step=  195, Dmax= 3.4e-02 nm, Epot= -3.55542e+04 Fmax= 5.76190e+02, atom= 1195
# Step=  196, Dmax= 4.1e-02 nm, Epot= -3.55560e+04 Fmax= 7.78599e+02, atom= 1195
# Step=  197, Dmax= 4.9e-02 nm, Epot= -3.55590e+04 Fmax= 6.26186e+02, atom= 1195
# Step=  199, Dmax= 2.9e-02 nm, Epot= -3.55830e+04 Fmax= 2.41203e+02, atom= 9865
# Step=  200, Dmax= 3.5e-02 nm, Epot= -3.55852e+04 Fmax= 7.57375e+02, atom= 986
# Step=  201, Dmax= 4.2e-02 nm, Epot= -3.55921e+04 Fmax= 6.16021e+02, atom= 1195
# Step=  203, Dmax= 2.5e-02 nm, Epot= -3.56086e+04 Fmax= 2.51342e+02, atom= 9645
# Step=  204, Dmax= 3.1e-02 nm, Epot= -3.56126e+04 Fmax= 7.37555e+02, atom= 964
# Step=  205, Dmax= 3.7e-02 nm, Epot= -3.56192e+04 Fmax= 4.46923e+02, atom= 1195
# Step=  207, Dmax= 2.2e-02 nm, Epot= -3.56318e+04 Fmax= 1.63615e+02, atom= 9865
# Step=  208, Dmax= 2.6e-02 nm, Epot= -3.56345e+04 Fmax= 7.04913e+02, atom= 986
# Step=  209, Dmax= 3.2e-02 nm, Epot= -3.56471e+04 Fmax= 3.72940e+02, atom= 1195
# Step=  211, Dmax= 1.9e-02 nm, Epot= -3.56560e+04 Fmax= 1.86962e+02, atom= 9645
# Step=  213, Dmax= 1.1e-02 nm, Epot= -3.56626e+04 Fmax= 1.48995e+02, atom= 1195
# Step=  214, Dmax= 1.4e-02 nm, Epot= -3.56678e+04 Fmax= 2.75894e+02, atom= 1
# Step=  215, Dmax= 1.6e-02 nm, Epot= -3.56739e+04 Fmax= 2.71636e+02, atom= 1
# Step=  216, Dmax= 2.0e-02 nm, Epot= -3.56763e+04 Fmax= 4.60009e+02, atom= 1
# Step=  217, Dmax= 2.4e-02 nm, Epot= -3.56846e+04 Fmax= 3.50310e+02, atom= 1
# Step=  219, Dmax= 1.4e-02 nm, Epot= -3.56923e+04 Fmax= 1.70678e+02, atom= 1
# Step=  220, Dmax= 1.7e-02 nm, Epot= -3.56976e+04 Fmax= 3.77997e+02, atom= 1
# Step=  221, Dmax= 2.0e-02 nm, Epot= -3.57033e+04 Fmax= 3.67633e+02, atom= 1
# Step=  222, Dmax= 2.5e-02 nm, Epot= -3.57062e+04 Fmax= 4.67396e+02, atom= 1
# Step=  223, Dmax= 2.9e-02 nm, Epot= -3.57087e+04 Fmax= 6.00387e+02, atom= 1
# Step=  224, Dmax= 3.5e-02 nm, Epot= -3.57119e+04 Fmax= 6.24984e+02, atom= 1
# Step=  226, Dmax= 2.1e-02 nm, Epot= -3.57261e+04 Fmax= 1.37789e+02, atom= 1
# Step=  227, Dmax= 2.5e-02 nm, Epot= -3.57305e+04 Fmax= 6.62493e+02, atom= 1
# Step=  228, Dmax= 3.1e-02 nm, Epot= -3.57418e+04 Fmax= 4.27215e+02, atom= 1
# Step=  230, Dmax= 1.8e-02 nm, Epot= -3.57488e+04 Fmax= 2.05094e+02, atom= 1
# Step=  232, Dmax= 1.1e-02 nm, Epot= -3.57535e+04 Fmax= 2.07216e+02, atom= 1
# Step=  233, Dmax= 1.3e-02 nm, Epot= -3.57582e+04 Fmax= 2.34932e+02, atom= 1
# Step=  234, Dmax= 1.6e-02 nm, Epot= -3.57622e+04 Fmax= 3.54022e+02, atom= 1
# Step=  235, Dmax= 1.9e-02 nm, Epot= -3.57671e+04 Fmax= 3.01251e+02, atom= 1
# Step=  236, Dmax= 2.3e-02 nm, Epot= -3.57681e+04 Fmax= 5.38839e+02, atom= 1
# Step=  237, Dmax= 2.7e-02 nm, Epot= -3.57747e+04 Fmax= 4.19266e+02, atom= 1
# Step=  239, Dmax= 1.6e-02 nm, Epot= -3.57825e+04 Fmax= 1.79156e+02, atom= 1
# Step=  240, Dmax= 2.0e-02 nm, Epot= -3.57855e+04 Fmax= 4.73805e+02, atom= 1
# Step=  241, Dmax= 2.4e-02 nm, Epot= -3.57920e+04 Fmax= 3.79472e+02, atom= 1
# Step=  243, Dmax= 1.4e-02 nm, Epot= -3.57983e+04 Fmax= 1.12530e+02, atom= 1
# Step=  244, Dmax= 1.7e-02 nm, Epot= -3.58016e+04 Fmax= 5.47454e+02, atom= 1
# Step=  245, Dmax= 2.0e-02 nm, Epot= -3.58118e+04 Fmax= 1.76539e+02, atom= 1
# Step=  247, Dmax= 1.2e-02 nm, Epot= -3.58157e+04 Fmax= 2.87535e+02, atom= 1
# Step=  248, Dmax= 1.5e-02 nm, Epot= -3.58201e+04 Fmax= 2.24332e+02, atom= 1
# Step=  249, Dmax= 1.8e-02 nm, Epot= -3.58221e+04 Fmax= 4.31699e+02, atom= 1
# Step=  250, Dmax= 2.1e-02 nm, Epot= -3.58277e+04 Fmax= 3.13369e+02, atom= 1
# Step=  252, Dmax= 1.3e-02 nm, Epot= -3.58330e+04 Fmax= 1.53047e+02, atom= 1
# Step=  253, Dmax= 1.5e-02 nm, Epot= -3.58367e+04 Fmax= 3.56889e+02, atom= 1
# Step=  254, Dmax= 1.8e-02 nm, Epot= -3.58415e+04 Fmax= 3.06506e+02, atom= 1
# Step=  255, Dmax= 2.2e-02 nm, Epot= -3.58426e+04 Fmax= 4.55060e+02, atom= 1
# Step=  256, Dmax= 2.6e-02 nm, Epot= -3.58458e+04 Fmax= 4.95758e+02, atom= 1
# Step=  258, Dmax= 1.6e-02 nm, Epot= -3.58545e+04 Fmax= 6.91080e+01, atom= 2
# Step=  259, Dmax= 1.9e-02 nm, Epot= -3.58593e+04 Fmax= 6.22489e+02, atom= 1
# Step=  260, Dmax= 2.3e-02 nm, Epot= -3.58727e+04 Fmax= 2.07454e+02, atom= 1
# Step=  262, Dmax= 1.4e-02 nm, Epot= -3.58755e+04 Fmax= 3.06134e+02, atom= 1
# Step=  263, Dmax= 1.6e-02 nm, Epot= -3.58791e+04 Fmax= 2.73993e+02, atom= 1
# Step=  264, Dmax= 2.0e-02 nm, Epot= -3.58799e+04 Fmax= 4.47701e+02, atom= 1
# Step=  265, Dmax= 2.4e-02 nm, Epot= -3.58841e+04 Fmax= 3.89591e+02, atom= 1
# Step=  267, Dmax= 1.4e-02 nm, Epot= -3.58906e+04 Fmax= 1.23907e+02, atom= 1
# Step=  268, Dmax= 1.7e-02 nm, Epot= -3.58934e+04 Fmax= 4.43229e+02, atom= 1
# Step=  269, Dmax= 2.0e-02 nm, Epot= -3.58993e+04 Fmax= 2.84672e+02, atom= 1
# Step=  271, Dmax= 1.2e-02 nm, Epot= -3.59033e+04 Fmax= 1.42459e+02, atom= 1
# Step=  272, Dmax= 1.5e-02 nm, Epot= -3.59051e+04 Fmax= 4.00078e+02, atom= 1
# Step=  273, Dmax= 1.8e-02 nm, Epot= -3.59105e+04 Fmax= 2.24009e+02, atom= 1
# Step=  275, Dmax= 1.1e-02 nm, Epot= -3.59141e+04 Fmax= 1.62508e+02, atom= 1
# Step=  276, Dmax= 1.3e-02 nm, Epot= -3.59168e+04 Fmax= 2.75700e+02, atom= 1
# Step=  277, Dmax= 1.5e-02 nm, Epot= -3.59199e+04 Fmax= 2.74690e+02, atom= 1
# Step=  278, Dmax= 1.8e-02 nm, Epot= -3.59216e+04 Fmax= 3.65865e+02, atom= 1
# Step=  279, Dmax= 2.2e-02 nm, Epot= -3.59238e+04 Fmax= 4.22608e+02, atom= 1
# Step=  280, Dmax= 2.6e-02 nm, Epot= -3.59245e+04 Fmax= 5.06660e+02, atom= 1
# Step=  282, Dmax= 1.6e-02 nm, Epot= -3.59338e+04 Fmax= 5.84190e+01, atom= 1
# Step=  283, Dmax= 1.9e-02 nm, Epot= -3.59436e+04 Fmax= 5.35710e+02, atom= 1
# Step=  284, Dmax= 2.3e-02 nm, Epot= -3.59512e+04 Fmax= 2.57280e+02, atom= 1
# Step=  286, Dmax= 1.4e-02 nm, Epot= -3.59543e+04 Fmax= 2.20696e+02, atom= 1
# Step=  287, Dmax= 1.6e-02 nm, Epot= -3.59556e+04 Fmax= 3.68179e+02, atom= 1
# Step=  288, Dmax= 2.0e-02 nm, Epot= -3.59589e+04 Fmax= 3.27053e+02, atom= 1
# Step=  290, Dmax= 1.2e-02 nm, Epot= -3.59637e+04 Fmax= 9.61047e+01, atom= 1
# Step=  291, Dmax= 1.4e-02 nm, Epot= -3.59670e+04 Fmax= 3.84629e+02, atom= 1
# Step=  292, Dmax= 1.7e-02 nm, Epot= -3.59721e+04 Fmax= 2.17996e+02, atom= 1
# Step=  294, Dmax= 1.0e-02 nm, Epot= -3.59750e+04 Fmax= 1.39009e+02, atom= 1
# Step=  295, Dmax= 1.2e-02 nm, Epot= -3.59772e+04 Fmax= 3.04098e+02, atom= 1
# Step=  296, Dmax= 1.5e-02 nm, Epot= -3.59807e+04 Fmax= 2.15411e+02, atom= 1
# Step=  297, Dmax= 1.8e-02 nm, Epot= -3.59808e+04 Fmax= 4.19257e+02, atom= 1
# Step=  298, Dmax= 2.1e-02 nm, Epot= -3.59849e+04 Fmax= 3.32931e+02, atom= 1
# Step=  300, Dmax= 1.3e-02 nm, Epot= -3.59898e+04 Fmax= 1.21484e+02, atom= 1
# Step=  301, Dmax= 1.5e-02 nm, Epot= -3.59913e+04 Fmax= 4.03269e+02, atom= 1
# Step=  302, Dmax= 1.8e-02 nm, Epot= -3.59964e+04 Fmax= 2.43350e+02, atom= 1
# Step=  304, Dmax= 1.1e-02 nm, Epot= -3.59995e+04 Fmax= 1.41653e+02, atom= 1
# Step=  305, Dmax= 1.3e-02 nm, Epot= -3.60011e+04 Fmax= 3.32516e+02, atom= 1
# Step=  306, Dmax= 1.6e-02 nm, Epot= -3.60049e+04 Fmax= 2.27174e+02, atom= 1
# Step=  308, Dmax= 9.4e-03 nm, Epot= -3.60080e+04 Fmax= 1.12421e+02, atom= 1
# Step=  309, Dmax= 1.1e-02 nm, Epot= -3.60105e+04 Fmax= 2.82228e+02, atom= 1
# Step=  310, Dmax= 1.4e-02 nm, Epot= -3.60138e+04 Fmax= 2.02991e+02, atom= 1
# Step=  311, Dmax= 1.6e-02 nm, Epot= -3.60145e+04 Fmax= 3.71243e+02, atom= 1
# Step=  312, Dmax= 2.0e-02 nm, Epot= -3.60178e+04 Fmax= 3.25927e+02, atom= 1
# Step=  314, Dmax= 1.2e-02 nm, Epot= -3.60221e+04 Fmax= 9.02960e+01, atom= 1
# Step=  315, Dmax= 1.4e-02 nm, Epot= -3.60235e+04 Fmax= 4.25493e+02, atom= 1
# Step=  316, Dmax= 1.7e-02 nm, Epot= -3.60297e+04 Fmax= 1.82133e+02, atom= 1
# Step=  318, Dmax= 1.0e-02 nm, Epot= -3.60321e+04 Fmax= 1.85462e+02, atom= 1
# Step=  319, Dmax= 1.2e-02 nm, Epot= -3.60340e+04 Fmax= 2.45356e+02, atom= 1
# Step=  320, Dmax= 1.5e-02 nm, Epot= -3.60361e+04 Fmax= 2.78630e+02, atom= 1
# Step=  321, Dmax= 1.8e-02 nm, Epot= -3.60374e+04 Fmax= 3.42600e+02, atom= 1
# Step=  322, Dmax= 2.1e-02 nm, Epot= -3.60386e+04 Fmax= 4.08885e+02, atom= 1
# Step=  323, Dmax= 2.5e-02 nm, Epot= -3.60388e+04 Fmax= 4.87381e+02, atom= 1
# Step=  325, Dmax= 1.5e-02 nm, Epot= -3.60472e+04 Fmax= 5.07597e+01, atom= 1
# Step=  326, Dmax= 1.8e-02 nm, Epot= -3.60540e+04 Fmax= 5.43692e+02, atom= 1
# Step=  327, Dmax= 2.2e-02 nm, Epot= -3.60617e+04 Fmax= 2.12160e+02, atom= 1
# Step=  329, Dmax= 1.3e-02 nm, Epot= -3.60635e+04 Fmax= 2.48500e+02, atom= 1
# Step=  330, Dmax= 1.6e-02 nm, Epot= -3.60649e+04 Fmax= 3.11222e+02, atom= 1
# Step=  331, Dmax= 1.9e-02 nm, Epot= -3.60662e+04 Fmax= 3.54562e+02, atom= 1
# Step=  332, Dmax= 2.3e-02 nm, Epot= -3.60665e+04 Fmax= 4.51495e+02, atom= 1
# Step=  333, Dmax= 2.7e-02 nm, Epot= -3.60668e+04 Fmax= 5.10144e+02, atom= 1
# Step=  335, Dmax= 1.6e-02 nm, Epot= -3.60756e+04 Fmax= 6.74118e+01, atom= 1
# Step=  336, Dmax= 2.0e-02 nm, Epot= -3.60776e+04 Fmax= 5.80685e+02, atom= 1
# Step=  337, Dmax= 2.3e-02 nm, Epot= -3.60862e+04 Fmax= 2.35217e+02, atom= 1
# Step=  339, Dmax= 1.4e-02 nm, Epot= -3.60879e+04 Fmax= 2.58048e+02, atom= 1
# Step=  340, Dmax= 1.7e-02 nm, Epot= -3.60888e+04 Fmax= 3.43735e+02, atom= 1
# Step=  341, Dmax= 2.0e-02 nm, Epot= -3.60901e+04 Fmax= 3.70068e+02, atom= 1
# Step=  343, Dmax= 1.2e-02 nm, Epot= -3.60952e+04 Fmax= 6.18616e+01, atom= 1
# Step=  344, Dmax= 1.5e-02 nm, Epot= -3.60986e+04 Fmax= 4.24871e+02, atom= 1
# Step=  345, Dmax= 1.8e-02 nm, Epot= -3.61040e+04 Fmax= 1.91065e+02, atom= 1
# Step=  347, Dmax= 1.1e-02 nm, Epot= -3.61060e+04 Fmax= 1.75086e+02, atom= 1
# Step=  348, Dmax= 1.3e-02 nm, Epot= -3.61072e+04 Fmax= 2.77316e+02, atom= 1
# Step=  349, Dmax= 1.5e-02 nm, Epot= -3.61093e+04 Fmax= 2.53534e+02, atom= 1
# Step=  351, Dmax= 9.1e-03 nm, Epot= -3.61123e+04 Fmax= 7.07109e+01, atom= 1
# Step=  352, Dmax= 1.1e-02 nm, Epot= -3.61153e+04 Fmax= 2.96095e+02, atom= 1
# Step=  353, Dmax= 1.3e-02 nm, Epot= -3.61185e+04 Fmax= 1.67890e+02, atom= 1
# Step=  355, Dmax= 7.8e-03 nm, Epot= -3.61205e+04 Fmax= 1.04340e+02, atom= 1
# Step=  356, Dmax= 9.4e-03 nm, Epot= -3.61224e+04 Fmax= 2.38125e+02, atom= 1
# Step=  357, Dmax= 1.1e-02 nm, Epot= -3.61248e+04 Fmax= 1.57187e+02, atom= 1
# Step=  358, Dmax= 1.4e-02 nm, Epot= -3.61254e+04 Fmax= 3.32352e+02, atom= 1
# Step=  359, Dmax= 1.6e-02 nm, Epot= -3.61285e+04 Fmax= 2.39318e+02, atom= 1
# Step=  361, Dmax= 9.8e-03 nm, Epot= -3.61313e+04 Fmax= 1.10281e+02, atom= 1
# Step=  362, Dmax= 1.2e-02 nm, Epot= -3.61328e+04 Fmax= 2.89430e+02, atom= 1
# Step=  363, Dmax= 1.4e-02 nm, Epot= -3.61357e+04 Fmax= 2.10638e+02, atom= 1
# Step=  365, Dmax= 8.4e-03 nm, Epot= -3.61381e+04 Fmax= 8.23606e+01, atom= 1
# Step=  366, Dmax= 1.0e-02 nm, Epot= -3.61401e+04 Fmax= 2.90417e+02, atom= 1
# Step=  367, Dmax= 1.2e-02 nm, Epot= -3.61434e+04 Fmax= 1.35064e+02, atom= 1
# Step=  369, Dmax= 7.3e-03 nm, Epot= -3.61453e+04 Fmax= 1.29293e+02, atom= 1
# Step=  370, Dmax= 8.7e-03 nm, Epot= -3.61472e+04 Fmax= 1.70942e+02, atom= 1
# Step=  371, Dmax= 1.0e-02 nm, Epot= -3.61491e+04 Fmax= 2.06778e+02, atom= 1
# Step=  372, Dmax= 1.3e-02 nm, Epot= -3.61508e+04 Fmax= 2.29434e+02, atom= 1
# Step=  373, Dmax= 1.5e-02 nm, Epot= -3.61519e+04 Fmax= 3.11444e+02, atom= 1
# Step=  374, Dmax= 1.8e-02 nm, Epot= -3.61536e+04 Fmax= 3.20408e+02, atom= 1
# Step=  376, Dmax= 1.1e-02 nm, Epot= -3.61576e+04 Fmax= 6.62420e+01, atom= 1
# Step=  377, Dmax= 1.3e-02 nm, Epot= -3.61610e+04 Fmax= 3.61137e+02, atom= 1
# Step=  378, Dmax= 1.6e-02 nm, Epot= -3.61651e+04 Fmax= 1.91301e+02, atom= 1
# Step=  380, Dmax= 9.4e-03 nm, Epot= -3.61672e+04 Fmax= 1.32031e+02, atom= 1
# Step=  381, Dmax= 1.1e-02 nm, Epot= -3.61686e+04 Fmax= 2.76275e+02, atom= 1
# Step=  382, Dmax= 1.4e-02 nm, Epot= -3.61712e+04 Fmax= 1.93262e+02, atom= 1
# Step=  384, Dmax= 8.1e-03 nm, Epot= -3.61735e+04 Fmax= 9.79530e+01, atom= 1
# Step=  385, Dmax= 9.7e-03 nm, Epot= -3.61757e+04 Fmax= 2.29059e+02, atom= 1
# Step=  386, Dmax= 1.2e-02 nm, Epot= -3.61780e+04 Fmax= 1.87993e+02, atom= 1
# Step=  387, Dmax= 1.4e-02 nm, Epot= -3.61791e+04 Fmax= 2.92793e+02, atom= 1
# Step=  388, Dmax= 1.7e-02 nm, Epot= -3.61810e+04 Fmax= 3.05639e+02, atom= 1
# Step=  389, Dmax= 2.0e-02 nm, Epot= -3.61814e+04 Fmax= 3.92810e+02, atom= 1
# Step=  390, Dmax= 2.4e-02 nm, Epot= -3.61821e+04 Fmax= 4.65899e+02, atom= 1
# Step=  392, Dmax= 1.5e-02 nm, Epot= -3.61889e+04 Fmax= 4.18906e+01, atom= 1
# Step=  393, Dmax= 1.7e-02 nm, Epot= -3.61908e+04 Fmax= 6.46819e+02, atom= 1
# Step=  394, Dmax= 2.1e-02 nm, Epot= -3.62040e+04 Fmax= 9.89030e+01, atom= 1
# Step=  396, Dmax= 1.3e-02 nm, Epot= -3.62048e+04 Fmax= 3.65862e+02, atom= 1
# Step=  397, Dmax= 1.5e-02 nm, Epot= -3.62092e+04 Fmax= 1.61256e+02, atom= 1
# Step=  399, Dmax= 9.0e-03 nm, Epot= -3.62112e+04 Fmax= 1.65011e+02, atom= 1
# Step=  400, Dmax= 1.1e-02 nm, Epot= -3.62130e+04 Fmax= 2.04857e+02, atom= 1
# Step=  401, Dmax= 1.3e-02 nm, Epot= -3.62146e+04 Fmax= 2.60483e+02, atom= 1
# Step=  402, Dmax= 1.6e-02 nm, Epot= -3.62162e+04 Fmax= 2.77004e+02, atom= 1
# Step=  403, Dmax= 1.9e-02 nm, Epot= -3.62167e+04 Fmax= 3.88900e+02, atom= 1
# Step=  404, Dmax= 2.3e-02 nm, Epot= -3.62184e+04 Fmax= 3.89306e+02, atom= 1
# Step=  406, Dmax= 1.4e-02 nm, Epot= -3.62236e+04 Fmax= 8.58976e+01, atom= 1
# Step=  407, Dmax= 1.6e-02 nm, Epot= -3.62249e+04 Fmax= 4.44884e+02, atom= 1
# Step=  408, Dmax= 1.9e-02 nm, Epot= -3.62302e+04 Fmax= 2.35054e+02, atom= 1
# Step=  410, Dmax= 1.2e-02 nm, Epot= -3.62326e+04 Fmax= 1.64000e+02, atom= 1
# Step=  411, Dmax= 1.4e-02 nm, Epot= -3.62332e+04 Fmax= 3.36834e+02, atom= 1
# Step=  412, Dmax= 1.7e-02 nm, Epot= -3.62362e+04 Fmax= 2.42585e+02, atom= 1
# Step=  414, Dmax= 1.0e-02 nm, Epot= -3.62389e+04 Fmax= 1.14388e+02, atom= 1
# Step=  415, Dmax= 1.2e-02 nm, Epot= -3.62405e+04 Fmax= 2.90475e+02, atom= 1
# Step=  416, Dmax= 1.5e-02 nm, Epot= -3.62432e+04 Fmax= 2.21135e+02, atom= 1
# Step=  417, Dmax= 1.7e-02 nm, Epot= -3.62433e+04 Fmax= 3.73248e+02, atom= 1
# Step=  418, Dmax= 2.1e-02 nm, Epot= -3.62456e+04 Fmax= 3.61208e+02, atom= 1
# Step=  420, Dmax= 1.3e-02 nm, Epot= -3.62500e+04 Fmax= 7.16884e+01, atom= 1
# Step=  421, Dmax= 1.5e-02 nm, Epot= -3.62507e+04 Fmax= 4.86527e+02, atom= 1
# Step=  422, Dmax= 1.8e-02 nm, Epot= -3.62577e+04 Fmax= 1.42913e+02, atom= 1
# Step=  424, Dmax= 1.1e-02 nm, Epot= -3.62592e+04 Fmax= 2.46205e+02, atom= 1
# Step=  425, Dmax= 1.3e-02 nm, Epot= -3.62614e+04 Fmax= 2.01067e+02, atom= 1
# Step=  426, Dmax= 1.6e-02 nm, Epot= -3.62618e+04 Fmax= 3.53673e+02, atom= 1
# Step=  427, Dmax= 1.9e-02 nm, Epot= -3.62644e+04 Fmax= 2.92944e+02, atom= 1
# Step=  429, Dmax= 1.1e-02 nm, Epot= -3.62678e+04 Fmax= 1.02627e+02, atom= 1
# Step=  430, Dmax= 1.3e-02 nm, Epot= -3.62690e+04 Fmax= 3.46800e+02, atom= 1
# Step=  431, Dmax= 1.6e-02 nm, Epot= -3.62726e+04 Fmax= 2.19354e+02, atom= 1
# Step=  433, Dmax= 9.7e-03 nm, Epot= -3.62749e+04 Fmax= 1.12756e+02, atom= 1
# Step=  434, Dmax= 1.2e-02 nm, Epot= -3.62761e+04 Fmax= 3.05847e+02, atom= 1
# Step=  435, Dmax= 1.4e-02 nm, Epot= -3.62791e+04 Fmax= 1.76023e+02, atom= 1
# Step=  437, Dmax= 8.4e-03 nm, Epot= -3.62812e+04 Fmax= 1.21665e+02, atom= 1
# Step=  438, Dmax= 1.0e-02 nm, Epot= -3.62828e+04 Fmax= 2.18068e+02, atom= 1
# Step=  439, Dmax= 1.2e-02 nm, Epot= -3.62848e+04 Fmax= 2.08121e+02, atom= 1
# Step=  440, Dmax= 1.4e-02 nm, Epot= -3.62858e+04 Fmax= 2.86886e+02, atom= 1
# Step=  441, Dmax= 1.7e-02 nm, Epot= -3.62872e+04 Fmax= 3.24508e+02, atom= 1
# Step=  442, Dmax= 2.1e-02 nm, Epot= -3.62877e+04 Fmax= 3.93191e+02, atom= 1
# Step=  443, Dmax= 2.5e-02 nm, Epot= -3.62877e+04 Fmax= 4.84554e+02, atom= 1
# Step=  445, Dmax= 1.5e-02 nm, Epot= -3.62948e+04 Fmax= 3.68244e+01, atom= 1
# Step=  446, Dmax= 1.8e-02 nm, Epot= -3.62969e+04 Fmax= 6.60369e+02, atom= 1
# Step=  447, Dmax= 2.2e-02 nm, Epot= -3.63102e+04 Fmax= 1.04485e+02, atom= 1
# Step=  449, Dmax= 1.3e-02 nm, Epot= -3.63104e+04 Fmax= 3.63445e+02, atom= 1
# Step=  450, Dmax= 1.6e-02 nm, Epot= -3.63144e+04 Fmax= 1.77904e+02, atom= 1
# Step=  452, Dmax= 9.4e-03 nm, Epot= -3.63162e+04 Fmax= 1.53547e+02, atom= 1
# Step=  453, Dmax= 1.1e-02 nm, Epot= -3.63174e+04 Fmax= 2.28399e+02, atom= 1
# Step=  454, Dmax= 1.3e-02 nm, Epot= -3.63190e+04 Fmax= 2.45287e+02, atom= 1
# Step=  455, Dmax= 1.6e-02 nm, Epot= -3.63197e+04 Fmax= 3.08907e+02, atom= 1
# Step=  456, Dmax= 1.9e-02 nm, Epot= -3.63204e+04 Fmax= 3.70768e+02, atom= 1
# Step=  457, Dmax= 2.3e-02 nm, Epot= -3.63206e+04 Fmax= 4.30626e+02, atom= 1
# Step=  459, Dmax= 1.4e-02 nm, Epot= -3.63266e+04 Fmax= 5.54761e+01, atom= 1
# Step=  460, Dmax= 1.7e-02 nm, Epot= -3.63285e+04 Fmax= 4.83787e+02, atom= 1
# Step=  461, Dmax= 2.0e-02 nm, Epot= -3.63347e+04 Fmax= 2.11218e+02, atom= 1
# Step=  463, Dmax= 1.2e-02 nm, Epot= -3.63362e+04 Fmax= 2.01416e+02, atom= 1
# Step=  464, Dmax= 1.4e-02 nm, Epot= -3.63366e+04 Fmax= 3.07738e+02, atom= 1
# Step=  465, Dmax= 1.7e-02 nm, Epot= -3.63382e+04 Fmax= 2.89920e+02, atom= 1
# Step=  467, Dmax= 1.0e-02 nm, Epot= -3.63414e+04 Fmax= 7.47743e+01, atom= 1
# Step=  468, Dmax= 1.3e-02 nm, Epot= -3.63425e+04 Fmax= 3.38897e+02, atom= 1
# Step=  469, Dmax= 1.5e-02 nm, Epot= -3.63459e+04 Fmax= 1.83980e+02, atom= 1
# Step=  471, Dmax= 9.0e-03 nm, Epot= -3.63475e+04 Fmax= 1.23303e+02, atom= 1
# Step=  472, Dmax= 1.1e-02 nm, Epot= -3.63482e+04 Fmax= 2.60979e+02, atom= 1
# Step=  473, Dmax= 1.3e-02 nm, Epot= -3.63502e+04 Fmax= 1.84866e+02, atom= 1
# Step=  475, Dmax= 7.8e-03 nm, Epot= -3.63520e+04 Fmax= 8.95363e+01, atom= 1
# Step=  476, Dmax= 9.3e-03 nm, Epot= -3.63533e+04 Fmax= 2.22892e+02, atom= 1
# Step=  477, Dmax= 1.1e-02 nm, Epot= -3.63551e+04 Fmax= 1.70048e+02, atom= 1
# Step=  478, Dmax= 1.3e-02 nm, Epot= -3.63553e+04 Fmax= 2.87544e+02, atom= 1
# Step=  479, Dmax= 1.6e-02 nm, Epot= -3.63569e+04 Fmax= 2.76741e+02, atom= 1
# Step=  481, Dmax= 9.7e-03 nm, Epot= -3.63597e+04 Fmax= 5.60916e+01, atom= 1
# Step=  482, Dmax= 1.2e-02 nm, Epot= -3.63605e+04 Fmax= 3.70221e+02, atom= 1
# Step=  483, Dmax= 1.4e-02 nm, Epot= -3.63649e+04 Fmax= 1.12930e+02, atom= 1
# Step=  485, Dmax= 8.4e-03 nm, Epot= -3.63659e+04 Fmax= 1.86165e+02, atom= 1
# Step=  486, Dmax= 1.0e-02 nm, Epot= -3.63673e+04 Fmax= 1.57594e+02, atom= 1
# Step=  487, Dmax= 1.2e-02 nm, Epot= -3.63677e+04 Fmax= 2.68716e+02, atom= 1
# Step=  488, Dmax= 1.4e-02 nm, Epot= -3.63693e+04 Fmax= 2.28224e+02, atom= 1
# Step=  490, Dmax= 8.7e-03 nm, Epot= -3.63715e+04 Fmax= 7.62843e+01, atom= 1
# Step=  491, Dmax= 1.0e-02 nm, Epot= -3.63724e+04 Fmax= 2.68569e+02, atom= 1
# Step=  492, Dmax= 1.2e-02 nm, Epot= -3.63747e+04 Fmax= 1.67580e+02, atom= 1
# Step=  494, Dmax= 7.5e-03 nm, Epot= -3.63761e+04 Fmax= 8.78359e+01, atom= 1
# Step=  495, Dmax= 9.0e-03 nm, Epot= -3.63769e+04 Fmax= 2.34729e+02, atom= 1
# Step=  496, Dmax= 1.1e-02 nm, Epot= -3.63788e+04 Fmax= 1.35631e+02, atom= 1
# Step=  498, Dmax= 6.5e-03 nm, Epot= -3.63801e+04 Fmax= 9.37011e+01, atom= 1
# Step=  499, Dmax= 7.8e-03 nm, Epot= -3.63811e+04 Fmax= 1.67148e+02, atom= 1
# Step=  500, Dmax= 9.3e-03 nm, Epot= -3.63824e+04 Fmax= 1.61205e+02, atom= 1
# Step=  501, Dmax= 1.1e-02 nm, Epot= -3.63830e+04 Fmax= 2.19777e+02, atom= 1
# Step=  502, Dmax= 1.3e-02 nm, Epot= -3.63838e+04 Fmax= 2.51026e+02, atom= 1
# Step=  503, Dmax= 1.6e-02 nm, Epot= -3.63842e+04 Fmax= 3.01128e+02, atom= 1
# Step=  505, Dmax= 9.7e-03 nm, Epot= -3.63874e+04 Fmax= 3.57186e+01, atom= 1
# Step=  506, Dmax= 1.2e-02 nm, Epot= -3.63906e+04 Fmax= 3.28447e+02, atom= 1
# Step=  507, Dmax= 1.4e-02 nm, Epot= -3.63938e+04 Fmax= 1.52462e+02, atom= 1
# Step=  509, Dmax= 8.3e-03 nm, Epot= -3.63949e+04 Fmax= 1.31724e+02, atom= 1
# Step=  510, Dmax= 1.0e-02 nm, Epot= -3.63954e+04 Fmax= 2.21312e+02, atom= 1
# Step=  511, Dmax= 1.2e-02 nm, Epot= -3.63967e+04 Fmax= 1.90369e+02, atom= 1
# Step=  513, Dmax= 7.2e-03 nm, Epot= -3.63984e+04 Fmax= 6.20503e+01, atom= 1
# Step=  514, Dmax= 8.7e-03 nm, Epot= -3.63995e+04 Fmax= 2.24040e+02, atom= 1
# Step=  515, Dmax= 1.0e-02 nm, Epot= -3.64013e+04 Fmax= 1.37843e+02, atom= 1
# Step=  517, Dmax= 6.2e-03 nm, Epot= -3.64024e+04 Fmax= 7.39456e+01, atom= 1
# Step=  518, Dmax= 7.5e-03 nm, Epot= -3.64033e+04 Fmax= 1.93196e+02, atom= 1
# Step=  519, Dmax= 9.0e-03 nm, Epot= -3.64048e+04 Fmax= 1.14220e+02, atom= 1
# Step=  521, Dmax= 5.4e-03 nm, Epot= -3.64059e+04 Fmax= 7.58977e+01, atom= 1
# Step=  522, Dmax= 6.5e-03 nm, Epot= -3.64070e+04 Fmax= 1.40263e+02, atom= 1
# Step=  523, Dmax= 7.8e-03 nm, Epot= -3.64081e+04 Fmax= 1.31708e+02, atom= 1
# Step=  524, Dmax= 9.3e-03 nm, Epot= -3.64087e+04 Fmax= 1.84275e+02, atom= 1
# Step=  525, Dmax= 1.1e-02 nm, Epot= -3.64096e+04 Fmax= 2.05761e+02, atom= 1
# Step=  526, Dmax= 1.3e-02 nm, Epot= -3.64100e+04 Fmax= 2.52493e+02, atom= 1
# Step=  527, Dmax= 1.6e-02 nm, Epot= -3.64103e+04 Fmax= 3.06958e+02, atom= 1
# Step=  529, Dmax= 9.6e-03 nm, Epot= -3.64136e+04 Fmax= 3.47826e+01, atom= 1116
# Step=  530, Dmax= 1.2e-02 nm, Epot= -3.64165e+04 Fmax= 2.92558e+02, atom= 1
# Step=  531, Dmax= 1.4e-02 nm, Epot= -3.64189e+04 Fmax= 1.90961e+02, atom= 1
# Step=  533, Dmax= 8.3e-03 nm, Epot= -3.64206e+04 Fmax= 1.00478e+02, atom= 1
# Step=  534, Dmax= 1.0e-02 nm, Epot= -3.64208e+04 Fmax= 2.37986e+02, atom= 1
# Step=  535, Dmax= 1.2e-02 nm, Epot= -3.64224e+04 Fmax= 1.78112e+02, atom= 1
# Step=  537, Dmax= 7.2e-03 nm, Epot= -3.64239e+04 Fmax= 6.75547e+01, atom= 1
# Step=  538, Dmax= 8.6e-03 nm, Epot= -3.64244e+04 Fmax= 2.38944e+02, atom= 1
# Step=  539, Dmax= 1.0e-02 nm, Epot= -3.64264e+04 Fmax= 1.17233e+02, atom= 1
# Step=  541, Dmax= 6.2e-03 nm, Epot= -3.64274e+04 Fmax= 1.00653e+02, atom= 1
# Step=  542, Dmax= 7.5e-03 nm, Epot= -3.64282e+04 Fmax= 1.52165e+02, atom= 1
# Step=  543, Dmax= 9.0e-03 nm, Epot= -3.64291e+04 Fmax= 1.59309e+02, atom= 1
# Step=  544, Dmax= 1.1e-02 nm, Epot= -3.64296e+04 Fmax= 2.07161e+02, atom= 1
# Step=  545, Dmax= 1.3e-02 nm, Epot= -3.64303e+04 Fmax= 2.39781e+02, atom= 1
# Step=  546, Dmax= 1.5e-02 nm, Epot= -3.64304e+04 Fmax= 2.89862e+02, atom= 1
# Step=  548, Dmax= 9.3e-03 nm, Epot= -3.64335e+04 Fmax= 3.09146e+01, atom= 1116
# Step=  549, Dmax= 1.1e-02 nm, Epot= -3.64362e+04 Fmax= 3.23159e+02, atom= 1
# Step=  550, Dmax= 1.3e-02 nm, Epot= -3.64394e+04 Fmax= 1.32228e+02, atom= 1
# Step=  552, Dmax= 8.0e-03 nm, Epot= -3.64402e+04 Fmax= 1.40087e+02, atom= 1
# Step=  553, Dmax= 9.6e-03 nm, Epot= -3.64408e+04 Fmax= 1.92572e+02, atom= 1
# Step=  554, Dmax= 1.2e-02 nm, Epot= -3.64415e+04 Fmax= 2.01536e+02, atom= 1
# Step=  556, Dmax= 6.9e-03 nm, Epot= -3.64433e+04 Fmax= 3.76050e+01, atom= 1
# Step=  557, Dmax= 8.3e-03 nm, Epot= -3.64449e+04 Fmax= 2.35771e+02, atom= 1
# Step=  558, Dmax= 1.0e-02 nm, Epot= -3.64469e+04 Fmax= 1.06513e+02, atom= 1
# Step=  560, Dmax= 6.0e-03 nm, Epot= -3.64478e+04 Fmax= 9.61702e+01, atom= 1
# Step=  561, Dmax= 7.2e-03 nm, Epot= -3.64485e+04 Fmax= 1.53141e+02, atom= 1
# Step=  562, Dmax= 8.6e-03 nm, Epot= -3.64494e+04 Fmax= 1.40595e+02, atom= 1
# Step=  563, Dmax= 1.0e-02 nm, Epot= -3.64497e+04 Fmax= 2.17049e+02, atom= 1
# Step=  564, Dmax= 1.2e-02 nm, Epot= -3.64506e+04 Fmax= 2.07471e+02, atom= 1
# Step=  566, Dmax= 7.5e-03 nm, Epot= -3.64524e+04 Fmax= 4.90928e+01, atom= 1
# Step=  567, Dmax= 8.9e-03 nm, Epot= -3.64532e+04 Fmax= 2.48508e+02, atom= 1
# Step=  568, Dmax= 1.1e-02 nm, Epot= -3.64554e+04 Fmax= 1.18460e+02, atom= 1
# Step=  570, Dmax= 6.4e-03 nm, Epot= -3.64562e+04 Fmax= 9.97203e+01, atom= 1
# Step=  571, Dmax= 7.7e-03 nm, Epot= -3.64568e+04 Fmax= 1.67251e+02, atom= 1
# Step=  572, Dmax= 9.3e-03 nm, Epot= -3.64578e+04 Fmax= 1.48832e+02, atom= 1
# Step=  573, Dmax= 1.1e-02 nm, Epot= -3.64578e+04 Fmax= 2.34299e+02, atom= 1
# Step=  574, Dmax= 1.3e-02 nm, Epot= -3.64588e+04 Fmax= 2.22253e+02, atom= 1
# Step=  576, Dmax= 8.0e-03 nm, Epot= -3.64608e+04 Fmax= 5.29732e+01, atom= 1
# Step=  577, Dmax= 9.6e-03 nm, Epot= -3.64612e+04 Fmax= 2.68266e+02, atom= 1
# Step=  578, Dmax= 1.2e-02 nm, Epot= -3.64636e+04 Fmax= 1.24931e+02, atom= 1
# Step=  580, Dmax= 6.9e-03 nm, Epot= -3.64645e+04 Fmax= 1.09824e+02, atom= 1
# Step=  581, Dmax= 8.3e-03 nm, Epot= -3.64650e+04 Fmax= 1.75714e+02, atom= 1
# Step=  582, Dmax= 1.0e-02 nm, Epot= -3.64659e+04 Fmax= 1.64109e+02, atom= 1
# Step=  584, Dmax= 6.0e-03 nm, Epot= -3.64673e+04 Fmax= 4.14051e+01, atom= 1
# Step=  585, Dmax= 7.2e-03 nm, Epot= -3.64686e+04 Fmax= 1.98509e+02, atom= 1
# ...
# Step= 1610, Dmax= 4.5e-03 nm, Epot= -3.69212e+04 Fmax= 9.90004e+01, atom= 1
# Step= 1611, Dmax= 5.4e-03 nm, Epot= -3.69215e+04 Fmax= 8.33615e+01, atom= 1
# Step= 1613, Dmax= 3.2e-03 nm, Epot= -3.69218e+04 Fmax= 2.35606e+01, atom= 1
# Step= 1614, Dmax= 3.9e-03 nm, Epot= -3.69220e+04 Fmax= 1.11795e+02, atom= 1
# Step= 1615, Dmax= 4.6e-03 nm, Epot= -3.69224e+04 Fmax= 4.25867e+01, atom= 1
# Step= 1617, Dmax= 2.8e-03 nm, Epot= -3.69226e+04 Fmax= 5.31355e+01, atom= 1
# Step= 1618, Dmax= 3.3e-03 nm, Epot= -3.69228e+04 Fmax= 5.69864e+01, atom= 1
# Step= 1619, Dmax= 4.0e-03 nm, Epot= -3.69229e+04 Fmax= 8.03094e+01, atom= 1
# Step= 1620, Dmax= 4.8e-03 nm, Epot= -3.69231e+04 Fmax= 7.93238e+01, atom= 1
# Step= 1621, Dmax= 5.8e-03 nm, Epot= -3.69231e+04 Fmax= 1.17223e+02, atom= 1
# Step= 1622, Dmax= 6.9e-03 nm, Epot= -3.69233e+04 Fmax= 1.13831e+02, atom= 1
# Step= 1624, Dmax= 4.2e-03 nm, Epot= -3.69238e+04 Fmax= 2.70005e+01, atom= 1
# Step= 1625, Dmax= 5.0e-03 nm, Epot= -3.69239e+04 Fmax= 1.35696e+02, atom= 1
# Step= 1626, Dmax= 6.0e-03 nm, Epot= -3.69244e+04 Fmax= 6.71919e+01, atom= 1
# Step= 1628, Dmax= 3.6e-03 nm, Epot= -3.69246e+04 Fmax= 5.22426e+01, atom= 1
# Step= 1629, Dmax= 4.3e-03 nm, Epot= -3.69247e+04 Fmax= 9.50966e+01, atom= 1
# Step= 1630, Dmax= 5.2e-03 nm, Epot= -3.69249e+04 Fmax= 7.73350e+01, atom= 1
# Step= 1632, Dmax= 3.1e-03 nm, Epot= -3.69252e+04 Fmax= 2.80141e+01, atom= 1
# Step= 1633, Dmax= 3.7e-03 nm, Epot= -3.69253e+04 Fmax= 9.40451e+01, atom= 1
# Step= 1634, Dmax= 4.5e-03 nm, Epot= -3.69256e+04 Fmax= 5.76351e+01, atom= 1
# Step= 1636, Dmax= 2.7e-03 nm, Epot= -3.69258e+04 Fmax= 3.16764e+01, atom= 1
# Step= 1637, Dmax= 3.2e-03 nm, Epot= -3.69260e+04 Fmax= 7.90795e+01, atom= 1
# Step= 1638, Dmax= 3.9e-03 nm, Epot= -3.69262e+04 Fmax= 4.99279e+01, atom= 1
# Step= 1639, Dmax= 4.6e-03 nm, Epot= -3.69262e+04 Fmax= 1.08306e+02, atom= 1
# Step= 1640, Dmax= 5.6e-03 nm, Epot= -3.69265e+04 Fmax= 7.75472e+01, atom= 1
# Step= 1642, Dmax= 3.3e-03 nm, Epot= -3.69268e+04 Fmax= 3.56486e+01, atom= 1
# Step= 1643, Dmax= 4.0e-03 nm, Epot= -3.69269e+04 Fmax= 9.67147e+01, atom= 1
# Step= 1644, Dmax= 4.8e-03 nm, Epot= -3.69272e+04 Fmax= 6.62090e+01, atom= 1
# Step= 1646, Dmax= 2.9e-03 nm, Epot= -3.69274e+04 Fmax= 3.02117e+01, atom= 1
# Step= 1647, Dmax= 3.5e-03 nm, Epot= -3.69275e+04 Fmax= 8.85257e+01, atom= 1
# Step= 1648, Dmax= 4.2e-03 nm, Epot= -3.69278e+04 Fmax= 5.03108e+01, atom= 1
# Step= 1650, Dmax= 2.5e-03 nm, Epot= -3.69279e+04 Fmax= 3.44832e+01, atom= 1
# Step= 1651, Dmax= 3.0e-03 nm, Epot= -3.69281e+04 Fmax= 6.45729e+01, atom= 1
# Step= 1652, Dmax= 3.6e-03 nm, Epot= -3.69283e+04 Fmax= 5.73336e+01, atom= 1
# Step= 1653, Dmax= 4.3e-03 nm, Epot= -3.69284e+04 Fmax= 8.64235e+01, atom= 1
# Step= 1654, Dmax= 5.2e-03 nm, Epot= -3.69285e+04 Fmax= 8.88240e+01, atom= 1
# Step= 1655, Dmax= 6.2e-03 nm, Epot= -3.69285e+04 Fmax= 1.18898e+02, atom= 1
# Step= 1656, Dmax= 7.4e-03 nm, Epot= -3.69286e+04 Fmax= 1.33062e+02, atom= 1
# Step= 1658, Dmax= 4.5e-03 nm, Epot= -3.69292e+04 Fmax= 1.70477e+01, atom= 1
# Step= 1659, Dmax= 5.4e-03 nm, Epot= -3.69292e+04 Fmax= 1.67931e+02, atom= 1
# Step= 1660, Dmax= 6.4e-03 nm, Epot= -3.69300e+04 Fmax= 4.78413e+01, atom= 1
# Step= 1662, Dmax= 3.9e-03 nm, Epot= -3.69301e+04 Fmax= 8.35653e+01, atom= 1
# Step= 1663, Dmax= 4.6e-03 nm, Epot= -3.69303e+04 Fmax= 7.16676e+01, atom= 1
# Step= 1665, Dmax= 2.8e-03 nm, Epot= -3.69305e+04 Fmax= 2.24985e+01, atom= 1
# Step= 1666, Dmax= 3.3e-03 nm, Epot= -3.69307e+04 Fmax= 8.79936e+01, atom= 1
# Step= 1667, Dmax= 4.0e-03 nm, Epot= -3.69309e+04 Fmax= 4.76667e+01, atom= 1
# Step= 1669, Dmax= 2.4e-03 nm, Epot= -3.69311e+04 Fmax= 3.28130e+01, atom= 1
# Step= 1670, Dmax= 2.9e-03 nm, Epot= -3.69312e+04 Fmax= 6.55587e+01, atom= 1
# Step= 1671, Dmax= 3.5e-03 nm, Epot= -3.69314e+04 Fmax= 5.02592e+01, atom= 1
# Step= 1672, Dmax= 4.2e-03 nm, Epot= -3.69314e+04 Fmax= 9.08139e+01, atom= 1
# Step= 1673, Dmax= 5.0e-03 nm, Epot= -3.69316e+04 Fmax= 7.64387e+01, atom= 1
# Step= 1675, Dmax= 3.0e-03 nm, Epot= -3.69319e+04 Fmax= 2.47584e+01, atom= 1
# Step= 1676, Dmax= 3.6e-03 nm, Epot= -3.69320e+04 Fmax= 9.46300e+01, atom= 1
# Step= 1677, Dmax= 4.3e-03 nm, Epot= -3.69323e+04 Fmax= 5.11833e+01, atom= 1
# Step= 1679, Dmax= 2.6e-03 nm, Epot= -3.69324e+04 Fmax= 3.55234e+01, atom= 1
# Step= 1680, Dmax= 3.1e-03 nm, Epot= -3.69325e+04 Fmax= 7.00329e+01, atom= 1
# Step= 1681, Dmax= 3.7e-03 nm, Epot= -3.69327e+04 Fmax= 5.47165e+01, atom= 1
# Step= 1682, Dmax= 4.5e-03 nm, Epot= -3.69327e+04 Fmax= 9.67802e+01, atom= 1
# Step= 1683, Dmax= 5.4e-03 nm, Epot= -3.69329e+04 Fmax= 8.32838e+01, atom= 1
# Step= 1685, Dmax= 3.2e-03 nm, Epot= -3.69332e+04 Fmax= 2.54629e+01, atom= 1
# Step= 1686, Dmax= 3.9e-03 nm, Epot= -3.69332e+04 Fmax= 1.03338e+02, atom= 1
# Step= 1687, Dmax= 4.6e-03 nm, Epot= -3.69336e+04 Fmax= 5.33873e+01, atom= 1
# Step= 1689, Dmax= 2.8e-03 nm, Epot= -3.69337e+04 Fmax= 3.97299e+01, atom= 1
# Step= 1690, Dmax= 3.3e-03 nm, Epot= -3.69338e+04 Fmax= 7.35237e+01, atom= 1
# Step= 1691, Dmax= 4.0e-03 nm, Epot= -3.69340e+04 Fmax= 6.08802e+01, atom= 1
# Step= 1693, Dmax= 2.4e-03 nm, Epot= -3.69341e+04 Fmax= 2.03525e+01, atom= 1
# Step= 1694, Dmax= 2.9e-03 nm, Epot= -3.69343e+04 Fmax= 7.56298e+01, atom= 1
# Step= 1695, Dmax= 3.5e-03 nm, Epot= -3.69345e+04 Fmax= 4.14562e+01, atom= 1
# Step= 1696, Dmax= 4.1e-03 nm, Epot= -3.69345e+04 Fmax= 9.76373e+01, atom= 1
# Step= 1697, Dmax= 5.0e-03 nm, Epot= -3.69348e+04 Fmax= 7.09020e+01, atom= 1
# Step= 1699, Dmax= 3.0e-03 nm, Epot= -3.69350e+04 Fmax= 2.95588e+01, atom= 1
# Step= 1700, Dmax= 3.6e-03 nm, Epot= -3.69350e+04 Fmax= 9.23226e+01, atom= 1
# Step= 1701, Dmax= 4.3e-03 nm, Epot= -3.69353e+04 Fmax= 5.21481e+01, atom= 1
# Step= 1703, Dmax= 2.6e-03 nm, Epot= -3.69354e+04 Fmax= 3.52548e+01, atom= 1
# Step= 1704, Dmax= 3.1e-03 nm, Epot= -3.69355e+04 Fmax= 6.85571e+01, atom= 1
# Step= 1705, Dmax= 3.7e-03 nm, Epot= -3.69357e+04 Fmax= 5.72842e+01, atom= 1
# Step= 1706, Dmax= 4.5e-03 nm, Epot= -3.69357e+04 Fmax= 9.24837e+01, atom= 1
# Step= 1707, Dmax= 5.3e-03 nm, Epot= -3.69358e+04 Fmax= 8.86283e+01, atom= 1
# Step= 1709, Dmax= 3.2e-03 nm, Epot= -3.69361e+04 Fmax= 1.95729e+01, atom= 1
# Step= 1710, Dmax= 3.8e-03 nm, Epot= -3.69362e+04 Fmax= 1.11453e+02, atom= 1
# Step= 1711, Dmax= 4.6e-03 nm, Epot= -3.69365e+04 Fmax= 4.40145e+01, atom= 1
# Step= 1713, Dmax= 2.8e-03 nm, Epot= -3.69367e+04 Fmax= 4.99987e+01, atom= 1
# Step= 1714, Dmax= 3.3e-03 nm, Epot= -3.69368e+04 Fmax= 6.17427e+01, atom= 1
# Step= 1715, Dmax= 4.0e-03 nm, Epot= -3.69368e+04 Fmax= 7.35290e+01, atom= 1
# Step= 1716, Dmax= 4.8e-03 nm, Epot= -3.69369e+04 Fmax= 8.78182e+01, atom= 1
# Step= 1717, Dmax= 5.7e-03 nm, Epot= -3.69369e+04 Fmax= 1.06893e+02, atom= 1
# Step= 1719, Dmax= 3.4e-03 nm, Epot= -3.69373e+04 Fmax= 9.55533e+00, atom= 1
#
# writing lowest energy coordinates.
#
# Back Off! I just backed up m.gro to ./#m.gro.1#
#
# Steepest Descents converged to Fmax < 10 in 1720 steps
# Potential Energy  = -3.6937301e+04
# Maximum force     =  9.5553322e+00 on atom 1
# Norm of force     =  1.3290777e+00
#
# GROMACS reminds you: "Even if you are on the right track, you will get run over if you just sit there." (Will Rogers)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx grompp -f /mnt/f/AA_SIMS_WATER_IONS/MDPs/eq.mdp -c m.gro -p topol.top -o r.tpr -maxwarn 5
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
#
# WARNING 1 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/eq.mdp]:
#   The Berendsen thermostat does not generate the correct kinetic energy
#   distribution, and should not be used for new production simulations (in
#   our opinion). We would recommend the V-rescale thermostat.
#
#
# WARNING 2 [file /mnt/f/AA_SIMS_WATER_IONS/MDPs/eq.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   For isotropic scaling we would recommend the C-rescale barostat that also
#   ensures fast relaxation without oscillations, and for anisotropic scaling
#   you likely want to use the Parrinello-Rahman barostat.
#
# Number of degrees of freedom in T-Coupling group System is 3600.00
#
# There were 2 WARNINGs
#
# GROMACS reminds you: "Catholic School Girls Rule" (Red Hot Chili Peppers)
#
#                       :-) GROMACS - gmx mdrun, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx mdrun -v -deffnm r -nt 10
#
#
# Back Off! I just backed up r.log to ./#r.log.1#
# Reading file r.tpr, VERSION 2023.1 (single precision)
# Changing nstlist from 20 to 40, rlist from 1.142 to 1.23
#
# Using 1 MPI thread
# Using 10 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cpus
#       and the -pin option is set to auto: will not pin threads to cpus.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
#
# Back Off! I just backed up r.xtc to ./#r.xtc.1#
#
# Back Off! I just backed up r.edr to ./#r.edr.1#
# starting mdrun 'one molecule in water'
# 1000000 steps,  10000.0 ps.
# step 0
# Setting the LD random seed to -101199889
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Setting gen_seed to -42533134
#
# Velocities were taken from a Maxwell distribution at 310 K
# Analysing residue names:
# There are:  1194      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.187 nm, buffer size 0.087 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.142 nm, buffer size 0.042 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 69 Mb of data
# Step 100  Warning: pressure scaling more than 1%, mu: 1.01779 1.01779 1.01779
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
#
# Back Off! I just backed up r.gro to ./#r.gro.1#
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:      780.305       78.041      999.9
#                  (ns/day)    (hour/ns)
# Performance:    11071.049        0.002
#
# GROMACS reminds you: "I wanted to make a clever chemistry joke, but the best ones Argon." (39.948)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx grompp -f /mnt/f/AA_SIMS_WATER_IONS/MDPs/run.mdp -c r.gro -p topol.top -o p.tpr -maxwarn 5
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
# Number of degrees of freedom in T-Coupling group System is 3600.00
#
# GROMACS reminds you: "Fresh Air, Green Hair" (Frank Black)
#
#                       :-) GROMACS - gmx mdrun, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx mdrun -v -deffnm p -nt 10
#
#
# Back Off! I just backed up p.log to ./#p.log.1#
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Changing nstlist from 20 to 25, rlist from 1.258 to 1.316
#
# Using 1 MPI thread
# Using 10 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cpus
#       and the -pin option is set to auto: will not pin threads to cpus.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
#
# Back Off! I just backed up p.xtc to ./#p.xtc.1#
#
# Back Off! I just backed up p.edr to ./#p.edr.1#
# Setting the LD random seed to -1478542361
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
# Analysing residue names:
# There are:  1194      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# Determining Verlet buffer for a tolerance of 0.002 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.335 nm, buffer size 0.235 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.258 nm, buffer size 0.158 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 29 Mb of data
# starting mdrun 'one molecule in water'
# 50000000 steps, 1000000.0 ps.
# step 49999900, remaining wall clock time:     0 s
# Writing final coordinates.
#
# Back Off! I just backed up p.gro to ./#p.gro.1#
# step 50000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    36843.298     3684.341     1000.0
#                          1h01:24
#                  (ns/day)    (hour/ns)
# Performance:    23450.602        0.001
#
# GROMACS reminds you: "On the East coast, a purple patch, to show where the jolly pioneers of progress drink the jolly lager-beer" (Joseph Conrad)
#
#                      :-) GROMACS - gmx trjconv, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx trjconv -f p.xtc -s p.tpr -o pbc.xtc -pbc mol
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  1201 elements
# Group     1 (          Other) has  1201 elements
# Group     2 (           CER6) has     8 elements
# Group     3 (              W) has  1185 elements
# Group     4 (            ION) has     8 elements
# Reading frame       0 time    0.000
# Precision of p.xtc is 0.01 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up pbc.xtc to ./#pbc.xtc.1#
# Reading frame    4000 time 800000.000    ->  frame   3999 time 799800.000
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 2: 'CER6'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 2: 'CER6'
# Last frame       5000 time 1000000.000    ->  frame   4999 time 999800.000
#  ->  frame   5000 time 1000000.000
# Last written: frame   5000 time 1000000.000
#
#
# GROMACS reminds you: "You Look Better Upside Down" (Throwing Muses)
#
#                      :-) GROMACS - gmx trjconv, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx trjconv -f p.xtc -s p.tpr -o pbc.gro -pbc mol -b 0 -e 0
#
# Will write gro: Coordinate file in Gromos-87 format
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  1201 elements
# Group     1 (          Other) has  1201 elements
# Group     2 (           CER6) has     8 elements
# Group     3 (              W) has  1185 elements
# Group     4 (            ION) has     8 elements
# Reading frame       0 time    0.000
# Precision of p.xtc is 0.01 (nm)
#
# Back Off! I just backed up pbc.gro to ./#pbc.gro.1#
# Last frame          0 time    0.000
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "You Look Better Upside Down" (Throwing Muses)

# %%
    ###Correct for the PBC
    p = subprocess.Popen('gmx trjconv -f p.xtc -s p.tpr -o pbc.gro -pbc mol -b 0 -e 0'
                         , stdin=subprocess.PIPE, shell=True, universal_newlines=True)
    p.communicate(resname)
    p.wait()
    ###Correct for the PBC
    p = subprocess.Popen('gmx trjconv -f p.xtc -s p.tpr -o pbc.xtc -pbc mol'
                         , stdin=subprocess.PIPE, shell=True, universal_newlines=True)
    p.communicate(resname)
    p.wait()
# Out:
#                      :-) GROMACS - gmx trjconv, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx trjconv -f p.xtc -s p.tpr -o pbc.gro -pbc mol -b 0 -e 0
#
# Will write gro: Coordinate file in Gromos-87 format
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  1201 elements
# Group     1 (          Other) has  1201 elements
# Group     2 (           CER6) has     8 elements
# Group     3 (              W) has  1185 elements
# Group     4 (            ION) has     8 elements
# Reading frame       0 time    0.000
# Precision of p.xtc is 0.01 (nm)
#
# Back Off! I just backed up pbc.gro to ./#pbc.gro.2#
# Last frame          0 time    0.000
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "You Look Better Upside Down" (Throwing Muses)
#
#                      :-) GROMACS - gmx trjconv, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT
# Command line:
#   gmx trjconv -f p.xtc -s p.tpr -o pbc.xtc -pbc mol
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  1201 elements
# Group     1 (          Other) has  1201 elements
# Group     2 (           CER6) has     8 elements
# Group     3 (              W) has  1185 elements
# Group     4 (            ION) has     8 elements
# Reading frame       0 time    0.000
# Precision of p.xtc is 0.01 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up pbc.xtc to ./#pbc.xtc.2#
# Reading frame      30 time 6000.000    ->  frame     29 time 5800.000
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 2: 'CER6'
# Reading frame    4000 time 800000.000    ->  frame   3999 time 799800.000
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 2: 'CER6'
# Last frame       5000 time 1000000.000    ->  frame   4999 time 999800.000
#  ->  frame   5000 time 1000000.000
# Last written: frame   5000 time 1000000.000
#
#
# GROMACS reminds you: "Millions saw the apple fall, Newton was the only one who asked why?" (Bernard Baruch)
# 0

# %% [markdown]
# ### Measure bonded parameters
#
# this is iterative. There is a re_run fucntion, to use for when you have optimized the parameters

# %%
#os.chdir('CG_WAT')
## Open AA   
u_aa = md.Universe('../cg_good.gro',
                   '../cg.xtc')

## Open CG
u_cg = md.Universe('pbc.gro', 'pbc.xtc')
# Out:
# /home/ltr/anaconda3/envs/jupyter_env/lib/python3.10/site-packages/MDAnalysis/coordinates/XDR.py:240: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn("Reload offsets from trajectory\n "

# %%
#ang_hist_aa, dist_hist_aa, ang_aa, dist_aa = measure_bonded_terms_simple(dist_tgts, ang_tgts, u_aa, bead_names, resname, 'AA', stride=10)
ang_hist_aa, dist_hist_aa, dihed_hist_aa, ang_aa, dist_aa, dihed_aa   = measure_bonded_terms(dist_tgts, ang_tgts, dihed_tgts, u_aa, bead_names, resname, 'AA', stride=10)
# Out:
# Calculating distributions...
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
#ang_hist_cg, dist_hist_cg, ang_cg, dist_cg = measure_bonded_terms_simple(dist_tgts, ang_tgts, u_cg, bead_names, resname, 'CG', stride=10)
ang_hist_cg, dist_hist_cg, dihed_hist_cg, ang_cg, dist_cg, dihed_cg = measure_bonded_terms(dist_tgts, ang_tgts, dihed_tgts, u_cg, bead_names, resname, 'CG', stride=10)
# Out:
# Calculating distributions...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
for bond in List_bonds:
    HAA,BAA = np.histogram(np.array(dist_aa)[bond,:], bins=bins_dist, density=True)
    HCG,BCG = np.histogram(np.array(dist_cg)[bond,:], bins=bins_dist, density=True)

    plt.plot(bins_dist_x, HAA, label='AA', color='green')
    plt.plot(bins_dist_x, HCG, label='CG', color='orange')

    title = ' '.join(i for i in dist_tgts[bond[0]])
    plt.title(title) 
    plt.xlabel('Bond (nm)')
    plt.ylabel('Probability density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
    plt.savefig('{}_water_bond.png'.format(title), dpi=300, bbox_inches='tight')
    plt.show()

# %%
for angle in List_angles:
    HAA,BAA = np.histogram(np.array(ang_aa)[angle,:], bins=bins_angl, density=True)
    HCG,BCG = np.histogram(np.array(ang_cg)[angle,:], bins=bins_angl, density=True)

    plt.plot(bins_angl_x, HAA, label='AA', color='green')
    plt.plot(bins_angl_x, HCG, label='CG', color='orange')
    title = ' '.join(i for i in ang_tgts[angle[0]])
    plt.title(title) 
    plt.xlabel('Angle (°)')
    plt.ylabel('Probability density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
    plt.savefig('{}_water_angle.png'.format(title), dpi=300, bbox_inches='tight')
    plt.show()

# %%
for dihed in List_dihed:

    HAA,BAA = np.histogram(np.array(dihed_aa)[dihed,:], bins=bins_dihed, density=True)
    HCG,BCG = np.histogram(np.array(dihed_cg)[dihed,:], bins=bins_dihed, density=True)


    plt.plot(bins_dihed_x, HAA, label='AA')
    plt.plot(bins_dihed_x, HCG, label='CG')
    title = ' '.join(i for i in dihed_tgts[dihed[0]])
    plt.title(title) 
    plt.xlabel('Dihedral (°)')
    plt.ylabel('Probability density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
    plt.savefig('{}_water_dihedral.png'.format(title), dpi=300, bbox_inches='tight')
    plt.show()

# %%
pwd
# Out:
# '/mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT'

# %% [markdown]
# #### you can optimize the bonded parameters now and then re-run.
# Remember to check SASA as well

# %%
cg_dir =  os.getcwd()

os.chdir(cg_dir)

CG  = ['pbc.gro', #GRO
       'pbc.xtc'] #XTX

run_SASA('CG_SASA', CG, resname, cg_dir, bead_names, bead_sizes)

CG_xvg = '{}/CG_WAT/CG_SASA/resarea_SASA.xvg'.format(main_dir)
AA_xvg = '{}/AA/resarea_SASA.xvg'.format(main_dir)
plot_SASA(AA_xvg, CG_xvg, resname)
plt.savefig('SASA.png'.format(title), dpi=300, bbox_inches='tight')
# Out:
# entering /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA
# Command line:
#   gmx sasa -f ../pbc.xtc -s ../pbc.gro -n /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/index.ndx -ndots 4800 -probe 0.191 -or /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/resarea_SASA.xvg -o /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/SASA.xvg
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
# Reading frame       0 time    0.000
# Back Off! I just backed up /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/SASA.xvg to /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/#SASA.xvg.4#
# Last frame       5000 time 1000000.000
#
# Back Off! I just backed up /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/resarea_SASA.xvg to /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA/#resarea_SASA.xvg.4#
# Analyzed 5001 frames, last time 1000000.000
#
# GROMACS reminds you: "... and that dream of dreams, a computational model that predicts everything accurately." (Roald Hoffmann)
#
#                        :-) GROMACS - gmx sasa, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_WAT/CG_SASA
# Command line:
#   gmx sasa -s gro.gro -o temp.xvg -probe 0.191 -ndots 240 -q surface.pdb
#
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# Frank Eisenhaber and Philip Lijnzaad and Patrick Argos and Chris Sander and
# Michael Scharf
# The Double Cube Lattice Method: Efficient Approaches to Numerical Integration
# of Surface Area and Volume and to Dot Surface Contouring of Molecular
# Assemblies
# J. Comp. Chem. 16 (1995) pp. 273-284
# -------- -------- --- Thank You --- -------- --------
#
#
# Back Off! I just backed up temp.xvg to ./#temp.xvg.4#
#
# Back Off! I just backed up surface.pdb to ./#surface.pdb.4#
# Analyzed topology coordinates
#
# GROMACS reminds you: "... and that dream of dreams, a computational model that predicts everything accurately." (Roald Hoffmann)
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx sasa uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# SASA AA: [10.246  0.666]
# SASA CG: [9.39  0.809]
# percent difference between the models.
# 8.354479796993953

# %%
#re_run(resname, mdp_loc, maxwarn=5)

# %% [markdown]
# ## BL Later once you have fixes CER6

# %%
os.chdir(main_dir)
#os.mkdir('CG_BL')
os.chdir('CG_BL')

# %%
#os.system('cp {}/CG_WAT/initial_CG.itp .'.format(main_dir))

# %%
#os.system('python2.7 insane.py -l CER:30 -l POPC:70 -pbc cubic -x 5 -y 5 -z 10 -sol W -o mem.gro -p topol.top')
os.system('python2.7 insane.py -l CER6:30 -l POPC:70 -pbc cubic -x 5 -y 5 -z 10 -sol W -o mem.gro -p topol.top')
# Out:
# ; X: 5.000 (6 bins) Y: 5.000 (6 bins) in upper leaflet
# ; X: 5.000 (6 bins) Y: 5.000 (6 bins) in lower leaflet
# ; 36 lipids in upper leaflet, 36 lipids in lower leaflet
# ; NDX Solute 1 0
# ; Charge of protein: 0.000000
# ; NDX Membrane 1 760
# ; Charge of membrane: 0.000000
# ; Total charge: 0.000000
# ; NDX Solvent 761 2092
# ; NDX System 1 2092
# ; "I mean, the good stuff is just INSANE" --Julia Ormond
# 0

# %%
#os.system("sed -i 's/{}/KC2/g' initial_CG.itp".format(resname))
# !rm *.tpr
# Out:
# rm: cannot remove '*.tpr': No such file or directory

# %%
prepare_setup_BL('initial_CG.itp', mdp_loc_BL)
# Out:
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx grompp -f /mnt/f/BILAYERS/MDPs/min.mdp -c mem.gro -p topol.top -o memion.tpr -maxwarn 5
#
#
# WARNING 1 [file /mnt/f/BILAYERS/MDPs/min.mdp, line 331]:
#   Unknown left-hand 'QMMMscheme' in parameter file
#
#
#
# WARNING 2 [file /mnt/f/BILAYERS/MDPs/min.mdp, line 331]:
#   Unknown left-hand 'MMChargeScaleFactor' in parameter file
#
#
#
# NOTE 1 [file /mnt/f/BILAYERS/MDPs/min.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Number of degrees of freedom in T-Coupling group rest is 6273.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# There was 1 NOTE
#
# There were 2 WARNINGs
#
# GROMACS reminds you: "Here's something fun to do: Next time you approach a conversation say 'I want to talk to someone technical... Oh! There's a woman!' and walk straight over to her." (Patty Lopez)
#
#                       :-) GROMACS - gmx genion, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx genion -s memion.tpr -o memion.gro -p topol.top -pname NA -pq +1 -nname CL -nq -1 -neutral
#
# Reading file memion.tpr, VERSION 2023.1 (single precision)
# Reading file memion.tpr, VERSION 2023.1 (single precision)
# No ions to add, will just copy input configuration.
#
# Back Off! I just backed up memion.gro to ./#memion.gro.1#
#
# GROMACS reminds you: "Here's something fun to do: Next time you approach a conversation say 'I want to talk to someone technical... Oh! There's a woman!' and walk straight over to her." (Patty Lopez)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx grompp -f /mnt/f/BILAYERS/MDPs/min.mdp -c memion.gro -p topol.top -o memion_2.tpr -maxwarn 5
#
#
# WARNING 1 [file /mnt/f/BILAYERS/MDPs/min.mdp, line 331]:
#   Unknown left-hand 'QMMMscheme' in parameter file
#
#
#
# WARNING 2 [file /mnt/f/BILAYERS/MDPs/min.mdp, line 331]:
#   Unknown left-hand 'MMChargeScaleFactor' in parameter file
#
#
#
# NOTE 1 [file /mnt/f/BILAYERS/MDPs/min.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
# Setting the LD random seed to 1795075798
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
# Analysing residue names:
# There are:  1402      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 0 Mb of data
# Number of degrees of freedom in T-Coupling group rest is 6273.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# There was 1 NOTE
#
# There were 2 WARNINGs
#
# GROMACS reminds you: "Here's something fun to do: Next time you approach a conversation say 'I want to talk to someone technical... Oh! There's a woman!' and walk straight over to her." (Patty Lopez)
#
#                       :-) GROMACS - gmx genion, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx genion -s memion_2.tpr -o memion_2.gro -p topol.top -pname NA -pq +1 -nname CL -nq -1 -np 14 -nn 14
#
# Reading file memion_2.tpr, VERSION 2023.1 (single precision)
# Reading file memion_2.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  2092 elements
# Group     1 (          Other) has  2092 elements
# Group     2 (           CER6) has   160 elements
# Group     3 (           POPC) has   600 elements
# Group     4 (              W) has  1332 elements
# Select a group: Number of (1-atomic) solvent molecules: 1332
#
# Back Off! I just backed up topol.top to ./#topol.top.1#
# Using random seed -143673347.
# Replacing solvent molecule 1088 (atom 1848) with NA
# Replacing solvent molecule 1089 (atom 1849) with NA
# Replacing solvent molecule 858 (atom 1618) with NA
# Replacing solvent molecule 574 (atom 1334) with NA
# Replacing solvent molecule 118 (atom 878) with NA
# Replacing solvent molecule 1269 (atom 2029) with NA
# Replacing solvent molecule 757 (atom 1517) with NA
# Replacing solvent molecule 1260 (atom 2020) with NA
# Replacing solvent molecule 1266 (atom 2026) with NA
# Replacing solvent molecule 522 (atom 1282) with NA
# Replacing solvent molecule 1112 (atom 1872) with NA
# Replacing solvent molecule 927 (atom 1687) with NA
# Replacing solvent molecule 1127 (atom 1887) with NA
# Replacing solvent molecule 649 (atom 1409) with NA
# Replacing solvent molecule 65 (atom 825) with CL
# Replacing solvent molecule 532 (atom 1292) with CL
# Replacing solvent molecule 1321 (atom 2081) with CL
# Replacing solvent molecule 679 (atom 1439) with CL
# Replacing solvent molecule 55 (atom 815) with CL
# Replacing solvent molecule 119 (atom 879) with CL
# Replacing solvent molecule 720 (atom 1480) with CL
# Replacing solvent molecule 674 (atom 1434) with CL
# Replacing solvent molecule 461 (atom 1221) with CL
# Replacing solvent molecule 652 (atom 1412) with CL
# Replacing solvent molecule 415 (atom 1175) with CL
# Replacing solvent molecule 586 (atom 1346) with CL
# Replacing solvent molecule 1137 (atom 1897) with CL
# Replacing solvent molecule 665 (atom 1425) with CL
#
#
# Back Off! I just backed up memion_2.gro to ./#memion_2.gro.1#
#
# GROMACS reminds you: "Here's something fun to do: Next time you approach a conversation say 'I want to talk to someone technical... Oh! There's a woman!' and walk straight over to her." (Patty Lopez)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx grompp -f /mnt/f/BILAYERS/MDPs/min.mdp -c memion_2.gro -p topol.top -o m.tpr -maxwarn 5
#
#
# WARNING 1 [file /mnt/f/BILAYERS/MDPs/min.mdp, line 331]:
#   Unknown left-hand 'QMMMscheme' in parameter file
#
#
#
# WARNING 2 [file /mnt/f/BILAYERS/MDPs/min.mdp, line 331]:
#   Unknown left-hand 'MMChargeScaleFactor' in parameter file
#
#
#
# NOTE 1 [file /mnt/f/BILAYERS/MDPs/min.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
# Setting the LD random seed to 2141190135
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
# Analysing residue names:
# There are:  1402      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 0 Mb of data
# Will try to add 14 NA ions and 14 CL ions.
# Select a continuous group of solvent molecules
# Selected 4: 'W'
#
# Processing topology
# Replacing 28 solute molecules in topology file (topol.top)  by 14 NA and 14 CL ions.
# Number of degrees of freedom in T-Coupling group rest is 6273.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# There was 1 NOTE
#
# There were 2 WARNINGs
#
# GROMACS reminds you: "Never, I said never, compare with experiment" (Magnus Bergh)
#
#                       :-) GROMACS - gmx mdrun, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx mdrun -v -deffnm m -nt 5
#
#
# Back Off! I just backed up m.log to ./#m.log.1#
# Reading file m.tpr, VERSION 2023.1 (single precision)
# Using 1 MPI thread
# Using 5 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cpus
#       and the -pin option is set to auto: will not pin threads to cpus.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
#
# Back Off! I just backed up m.trr to ./#m.trr.1#
#
# Back Off! I just backed up m.edr to ./#m.edr.1#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+02
#    Number of steps    =          500
# Step=    0, Dmax= 1.0e-02 nm, Epot=  3.77146e+12 Fmax= 9.32370e+14, atom= 75
# Step=    1, Dmax= 1.0e-02 nm, Epot=  9.09713e+10 Fmax= 1.01555e+13, atom= 75
# Step=    2, Dmax= 1.2e-02 nm, Epot=  9.53632e+09 Fmax= 6.88988e+11, atom= 51
# Step=    3, Dmax= 1.4e-02 nm, Epot=  3.06317e+09 Fmax= 6.46254e+10, atom= 75
# Step=    4, Dmax= 1.7e-02 nm, Epot=  4.86174e+08 Fmax= 6.11647e+09, atom= 52
# Step=    5, Dmax= 2.1e-02 nm, Epot=  9.83642e+07 Fmax= 5.78452e+08, atom= 75
# Step=    6, Dmax= 2.5e-02 nm, Epot=  2.87243e+07 Fmax= 5.82845e+07, atom= 479
# Step=    7, Dmax= 3.0e-02 nm, Epot=  7.04179e+06 Fmax= 5.89551e+06, atom= 579
# Step=    8, Dmax= 3.6e-02 nm, Epot=  1.62659e+06 Fmax= 6.05853e+05, atom= 136
# Step=    9, Dmax= 4.3e-02 nm, Epot=  2.96664e+05 Fmax= 4.84597e+05, atom= 567
# Step=   10, Dmax= 5.2e-02 nm, Epot=  2.13993e+05 Fmax= 1.22322e+05, atom= 671
# Step=   11, Dmax= 6.2e-02 nm, Epot=  1.00815e+05 Fmax= 1.36604e+05, atom= 675
# Step=   12, Dmax= 7.4e-02 nm, Epot=  7.65796e+04 Fmax= 1.61112e+04, atom= 676
# Step=   13, Dmax= 8.9e-02 nm, Epot=  2.67558e+04 Fmax= 1.30542e+04, atom= 676
# Step=   14, Dmax= 1.1e-01 nm, Epot=  1.84347e+04 Fmax= 1.91135e+04, atom= 4
# Step=   15, Dmax= 1.3e-01 nm, Epot=  1.33406e+04 Fmax= 5.21619e+03, atom= 76
# Step=   16, Dmax= 1.5e-01 nm, Epot=  1.26191e+03 Fmax= 4.19109e+03, atom= 5
# Step=   17, Dmax= 1.8e-01 nm, Epot= -7.26070e+03 Fmax= 6.41180e+03, atom= 4
# Step=   18, Dmax= 2.2e-01 nm, Epot= -9.84952e+03 Fmax= 5.81563e+04, atom= 75
# Step=   19, Dmax= 2.7e-01 nm, Epot= -1.05204e+04 Fmax= 6.61505e+04, atom= 74
# Step=   20, Dmax= 3.2e-01 nm, Epot= -1.24719e+04 Fmax= 5.12862e+03, atom= 74
# Step=   21, Dmax= 3.8e-01 nm, Epot= -1.86098e+04 Fmax= 3.31473e+04, atom= 4
# Step=   23, Dmax= 2.3e-01 nm, Epot= -1.99792e+04 Fmax= 5.62498e+03, atom= 246
# Step=   24, Dmax= 2.8e-01 nm, Epot= -2.33414e+04 Fmax= 2.98014e+03, atom= 246
# Step=   26, Dmax= 1.7e-01 nm, Epot= -2.51888e+04 Fmax= 3.31156e+03, atom= 1874
# Step=   28, Dmax= 9.9e-02 nm, Epot= -2.59986e+04 Fmax= 3.19547e+04, atom= 1874
# Step=   29, Dmax= 1.2e-01 nm, Epot= -2.86211e+04 Fmax= 1.34288e+03, atom= 1559
# Step=   32, Dmax= 3.6e-02 nm, Epot= -3.09956e+04 Fmax= 9.14907e+02, atom= 1651
# Step=   33, Dmax= 4.3e-02 nm, Epot= -3.35625e+04 Fmax= 1.16381e+03, atom= 777
# Step=   34, Dmax= 5.2e-02 nm, Epot= -3.55868e+04 Fmax= 2.93202e+03, atom= 1559
# Step=   35, Dmax= 6.2e-02 nm, Epot= -3.81494e+04 Fmax= 1.20953e+03, atom= 1559
# Step=   36, Dmax= 7.4e-02 nm, Epot= -4.12572e+04 Fmax= 3.24357e+03, atom= 1248
# Step=   37, Dmax= 8.9e-02 nm, Epot= -4.29389e+04 Fmax= 4.47034e+03, atom= 2086
# Step=   38, Dmax= 1.1e-01 nm, Epot= -4.41053e+04 Fmax= 8.52099e+03, atom= 1415
# Step=   39, Dmax= 1.3e-01 nm, Epot= -4.46443e+04 Fmax= 1.60089e+04, atom= 1991
# Step=   40, Dmax= 1.5e-01 nm, Epot= -4.50640e+04 Fmax= 1.46325e+04, atom= 1476
# Step=   41, Dmax= 1.8e-01 nm, Epot= -4.54927e+04 Fmax= 8.68487e+03, atom= 2017
# Step=   43, Dmax= 1.1e-01 nm, Epot= -4.63387e+04 Fmax= 3.10065e+03, atom= 1015
# Step=   44, Dmax= 1.3e-01 nm, Epot= -4.77194e+04 Fmax= 9.75429e+03, atom= 1015
# Step=   45, Dmax= 1.6e-01 nm, Epot= -4.77920e+04 Fmax= 2.93692e+04, atom= 1678
# Step=   46, Dmax= 1.9e-01 nm, Epot= -4.81689e+04 Fmax= 1.97492e+04, atom= 1300
# Step=   48, Dmax= 1.1e-01 nm, Epot= -4.87039e+04 Fmax= 6.37363e+03, atom= 1300
# Step=   49, Dmax= 1.4e-01 nm, Epot= -4.95176e+04 Fmax= 3.02545e+03, atom= 1611
# Step=   50, Dmax= 1.7e-01 nm, Epot= -5.06146e+04 Fmax= 8.29907e+03, atom= 966
# Step=   51, Dmax= 2.0e-01 nm, Epot= -5.12290e+04 Fmax= 5.43319e+03, atom= 1320
# Step=   53, Dmax= 1.2e-01 nm, Epot= -5.19270e+04 Fmax= 2.76171e+03, atom= 1320
# Step=   54, Dmax= 1.4e-01 nm, Epot= -5.26392e+04 Fmax= 1.43385e+04, atom= 1244
# Step=   56, Dmax= 8.6e-02 nm, Epot= -5.30857e+04 Fmax= 4.45958e+03, atom= 762
# Step=   57, Dmax= 1.0e-01 nm, Epot= -5.35364e+04 Fmax= 3.15838e+03, atom= 1472
# Step=   58, Dmax= 1.2e-01 nm, Epot= -5.41817e+04 Fmax= 3.37575e+03, atom= 1020
# Step=   60, Dmax= 7.4e-02 nm, Epot= -5.45862e+04 Fmax= 1.18704e+03, atom= 8539
# Step=   61, Dmax= 8.9e-02 nm, Epot= -5.53977e+04 Fmax= 3.13875e+03, atom= 2069
# Step=   62, Dmax= 1.1e-01 nm, Epot= -5.58871e+04 Fmax= 6.21799e+03, atom= 2087
# Step=   64, Dmax= 6.4e-02 nm, Epot= -5.60717e+04 Fmax= 1.38116e+03, atom= 2065
# Step=   65, Dmax= 7.7e-02 nm, Epot= -5.63132e+04 Fmax= 1.89118e+04, atom= 2087
# Step=   66, Dmax= 9.2e-02 nm, Epot= -5.66525e+04 Fmax= 1.30040e+03, atom= 2087
# Step=   68, Dmax= 5.5e-02 nm, Epot= -5.71420e+04 Fmax= 4.62090e+03, atom= 2069
# Step=   69, Dmax= 6.6e-02 nm, Epot= -5.72558e+04 Fmax= 1.16396e+03, atom= 2083
# Step=   70, Dmax= 8.0e-02 nm, Epot= -5.75143e+04 Fmax= 1.65541e+04, atom= 2065
# Step=   71, Dmax= 9.6e-02 nm, Epot= -5.77419e+04 Fmax= 1.78307e+03, atom= 2065
# Step=   72, Dmax= 1.1e-01 nm, Epot= -5.77835e+04 Fmax= 2.74805e+04, atom= 2087
# Step=   73, Dmax= 1.4e-01 nm, Epot= -5.82511e+04 Fmax= 2.09773e+03, atom= 2087
# Step=   75, Dmax= 8.3e-02 nm, Epot= -5.85770e+04 Fmax= 6.09869e+03, atom= 2069
# Step=   76, Dmax= 9.9e-02 nm, Epot= -5.86130e+04 Fmax= 1.76288e+03, atom= 2069
# Step=   77, Dmax= 1.2e-01 nm, Epot= -5.88368e+04 Fmax= 2.25701e+04, atom= 2069
# Step=   78, Dmax= 1.4e-01 nm, Epot= -5.90989e+04 Fmax= 1.06109e+03, atom= 2083
# Step=   81, Dmax= 4.3e-02 nm, Epot= -5.93764e+04 Fmax= 3.45369e+03, atom= 2065
# Step=   82, Dmax= 5.1e-02 nm, Epot= -5.94483e+04 Fmax= 1.06854e+03, atom= 2065
# Step=   83, Dmax= 6.2e-02 nm, Epot= -5.96966e+04 Fmax= 1.17905e+04, atom= 2087
# Step=   84, Dmax= 7.4e-02 nm, Epot= -5.98383e+04 Fmax= 1.10025e+03, atom= 2065
# Step=   86, Dmax= 4.4e-02 nm, Epot= -6.00867e+04 Fmax= 3.82794e+03, atom= 2069
# Step=   87, Dmax= 5.3e-02 nm, Epot= -6.01454e+04 Fmax= 9.08022e+02, atom= 2083
# Step=   88, Dmax= 6.4e-02 nm, Epot= -6.02699e+04 Fmax= 1.46585e+04, atom= 2069
# Step=   89, Dmax= 7.7e-02 nm, Epot= -6.04536e+04 Fmax= 9.09835e+02, atom= 2069
# Step=   91, Dmax= 4.6e-02 nm, Epot= -6.05611e+04 Fmax= 1.24607e+04, atom= 2065
# Step=   92, Dmax= 5.5e-02 nm, Epot= -6.07042e+04 Fmax= 1.21454e+03, atom= 2065
# Step=   94, Dmax= 3.3e-02 nm, Epot= -6.08599e+04 Fmax= 1.19210e+03, atom= 2069
# Step=   95, Dmax= 4.0e-02 nm, Epot= -6.09473e+04 Fmax= 9.71754e+02, atom= 2069
# Step=   96, Dmax= 4.8e-02 nm, Epot= -6.11116e+04 Fmax= 4.58505e+03, atom= 2069
# Step=   97, Dmax= 5.7e-02 nm, Epot= -6.11616e+04 Fmax= 9.79728e+02, atom= 2069
# Step=   99, Dmax= 3.4e-02 nm, Epot= -6.13424e+04 Fmax= 1.90939e+03, atom= 2065
# Step=  100, Dmax= 4.1e-02 nm, Epot= -6.13830e+04 Fmax= 1.42772e+03, atom= 2065
# Step=  101, Dmax= 4.9e-02 nm, Epot= -6.15130e+04 Fmax= 3.78932e+03, atom= 2065
# Step=  102, Dmax= 5.9e-02 nm, Epot= -6.15620e+04 Fmax= 1.37659e+03, atom= 2065
# Step=  104, Dmax= 3.6e-02 nm, Epot= -6.17413e+04 Fmax= 1.80365e+03, atom= 2069
# Step=  105, Dmax= 4.3e-02 nm, Epot= -6.17905e+04 Fmax= 1.09735e+03, atom= 2065
# Step=  106, Dmax= 5.1e-02 nm, Epot= -6.18453e+04 Fmax= 3.84640e+03, atom= 2069
# Step=  107, Dmax= 6.2e-02 nm, Epot= -6.19336e+04 Fmax= 1.06953e+03, atom= 2065
# Step=  109, Dmax= 3.7e-02 nm, Epot= -6.20759e+04 Fmax= 4.28907e+03, atom= 2065
# Step=  110, Dmax= 4.4e-02 nm, Epot= -6.21210e+04 Fmax= 1.17861e+03, atom= 2065
# Step=  112, Dmax= 2.7e-02 nm, Epot= -6.22392e+04 Fmax= 1.00386e+03, atom= 2084
# Step=  113, Dmax= 3.2e-02 nm, Epot= -6.22689e+04 Fmax= 1.75927e+03, atom= 2065
# Step=  114, Dmax= 3.8e-02 nm, Epot= -6.23536e+04 Fmax= 1.27787e+03, atom= 2065
# Setting the LD random seed to -1140905249
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
# Analysing residue names:
# There are:  1402      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# This run will generate roughly 0 Mb of data
# Step=  115, Dmax= 4.6e-02 nm, Epot= -6.24429e+04 Fmax= 4.66204e+03, atom= 2065
# Step=  116, Dmax= 5.5e-02 nm, Epot= -6.24556e+04 Fmax= 1.31698e+03, atom= 2065
# Step=  118, Dmax= 3.3e-02 nm, Epot= -6.25806e+04 Fmax= 1.48325e+03, atom= 2084
# Step=  119, Dmax= 4.0e-02 nm, Epot= -6.25983e+04 Fmax= 2.05291e+03, atom= 2065
# Step=  120, Dmax= 4.8e-02 nm, Epot= -6.26420e+04 Fmax= 1.46249e+03, atom= 2069
# Step=  121, Dmax= 5.7e-02 nm, Epot= -6.26523e+04 Fmax= 4.56911e+03, atom= 2084
# Step=  122, Dmax= 6.9e-02 nm, Epot= -6.26635e+04 Fmax= 1.14959e+03, atom= 2065
# Step=  124, Dmax= 4.1e-02 nm, Epot= -6.29014e+04 Fmax= 1.82897e+03, atom= 2065
# Step=  125, Dmax= 4.9e-02 nm, Epot= -6.29162e+04 Fmax= 1.30122e+03, atom= 2065
# Step=  127, Dmax= 3.0e-02 nm, Epot= -6.30337e+04 Fmax= 1.26079e+03, atom= 2069
# Step=  128, Dmax= 3.6e-02 nm, Epot= -6.30406e+04 Fmax= 2.94586e+03, atom= 2065
# Step=  129, Dmax= 4.3e-02 nm, Epot= -6.30708e+04 Fmax= 1.21847e+03, atom= 2065
# Step=  131, Dmax= 2.6e-02 nm, Epot= -6.31942e+04 Fmax= 7.78751e+02, atom= 2069
# Step=  133, Dmax= 1.5e-02 nm, Epot= -6.32316e+04 Fmax= 8.48805e+02, atom= 2065
# Step=  134, Dmax= 1.8e-02 nm, Epot= -6.32694e+04 Fmax= 1.15467e+03, atom= 2069
# Step=  135, Dmax= 2.2e-02 nm, Epot= -6.33077e+04 Fmax= 9.40147e+02, atom= 2069
# Step=  136, Dmax= 2.7e-02 nm, Epot= -6.33286e+04 Fmax= 2.50564e+03, atom= 2069
# Step=  137, Dmax= 3.2e-02 nm, Epot= -6.33721e+04 Fmax= 1.03264e+03, atom= 2069
# Step=  139, Dmax= 1.9e-02 nm, Epot= -6.34534e+04 Fmax= 8.34189e+02, atom= 2065
# Step=  140, Dmax= 2.3e-02 nm, Epot= -6.34834e+04 Fmax= 1.15841e+03, atom= 2065
# Step=  141, Dmax= 2.8e-02 nm, Epot= -6.35284e+04 Fmax= 1.94918e+03, atom= 2065
# Step=  142, Dmax= 3.3e-02 nm, Epot= -6.35504e+04 Fmax= 1.26968e+03, atom= 2065
# Step=  143, Dmax= 4.0e-02 nm, Epot= -6.35846e+04 Fmax= 4.28735e+03, atom= 2065
# Step=  144, Dmax= 4.8e-02 nm, Epot= -6.35926e+04 Fmax= 1.32496e+03, atom= 2065
# Step=  146, Dmax= 2.9e-02 nm, Epot= -6.37143e+04 Fmax= 6.09907e+02, atom= 2087
# Step=  148, Dmax= 1.7e-02 nm, Epot= -6.37535e+04 Fmax= 2.31815e+03, atom= 2065
# Step=  149, Dmax= 2.1e-02 nm, Epot= -6.37808e+04 Fmax= 8.62874e+02, atom= 2087
# Step=  150, Dmax= 2.5e-02 nm, Epot= -6.38018e+04 Fmax= 4.21554e+03, atom= 2065
# Step=  151, Dmax= 3.0e-02 nm, Epot= -6.38391e+04 Fmax= 1.04458e+03, atom= 2065
# Step=  153, Dmax= 1.8e-02 nm, Epot= -6.38912e+04 Fmax= 2.88896e+02, atom= 2065
# Step=  154, Dmax= 2.1e-02 nm, Epot= -6.40023e+04 Fmax= 1.21613e+03, atom= 2065
# Step=  155, Dmax= 2.6e-02 nm, Epot= -6.40633e+04 Fmax= 1.18843e+03, atom= 2065
# Step=  156, Dmax= 3.1e-02 nm, Epot= -6.40757e+04 Fmax= 1.30403e+03, atom= 2065
# Step=  157, Dmax= 3.7e-02 nm, Epot= -6.41382e+04 Fmax= 2.77233e+03, atom= 2065
# Step=  159, Dmax= 2.2e-02 nm, Epot= -6.41716e+04 Fmax= 8.72102e+02, atom= 2087
# Step=  160, Dmax= 2.6e-02 nm, Epot= -6.41749e+04 Fmax= 5.19187e+03, atom= 2065
# Step=  161, Dmax= 3.2e-02 nm, Epot= -6.42290e+04 Fmax= 1.06126e+03, atom= 2065
# Step=  163, Dmax= 1.9e-02 nm, Epot= -6.42826e+04 Fmax= 3.91959e+02, atom= 2065
# Step=  164, Dmax= 2.3e-02 nm, Epot= -6.43566e+04 Fmax= 1.21525e+03, atom= 2065
# Step=  165, Dmax= 2.7e-02 nm, Epot= -6.44160e+04 Fmax= 1.39750e+03, atom= 2065
# Step=  167, Dmax= 1.6e-02 nm, Epot= -6.44383e+04 Fmax= 8.11959e+02, atom= 2065
# Step=  168, Dmax= 2.0e-02 nm, Epot= -6.44638e+04 Fmax= 2.55521e+03, atom= 2065
# Step=  169, Dmax= 2.4e-02 nm, Epot= -6.44920e+04 Fmax= 9.88249e+02, atom= 2065
# Step=  171, Dmax= 1.4e-02 nm, Epot= -6.45367e+04 Fmax= 2.65661e+02, atom= 2088
# Step=  172, Dmax= 1.7e-02 nm, Epot= -6.46311e+04 Fmax= 9.28625e+02, atom= 2070
# Step=  173, Dmax= 2.1e-02 nm, Epot= -6.46763e+04 Fmax= 1.65349e+03, atom= 2065
# Step=  174, Dmax= 2.5e-02 nm, Epot= -6.46886e+04 Fmax= 1.13857e+03, atom= 2065
# Step=  175, Dmax= 3.0e-02 nm, Epot= -6.47193e+04 Fmax= 3.16445e+03, atom= 2065
# Step=  176, Dmax= 3.5e-02 nm, Epot= -6.47320e+04 Fmax= 1.23777e+03, atom= 2065
# Step=  178, Dmax= 2.1e-02 nm, Epot= -6.48118e+04 Fmax= 3.75763e+02, atom= 2088
# Step=  180, Dmax= 1.3e-02 nm, Epot= -6.48544e+04 Fmax= 1.87169e+03, atom= 2065
# Step=  181, Dmax= 1.5e-02 nm, Epot= -6.48802e+04 Fmax= 6.51289e+02, atom= 2065
# Step=  182, Dmax= 1.8e-02 nm, Epot= -6.48981e+04 Fmax= 3.11416e+03, atom= 2065
# Step=  183, Dmax= 2.2e-02 nm, Epot= -6.49291e+04 Fmax= 8.63951e+02, atom= 2065
# Step=  185, Dmax= 1.3e-02 nm, Epot= -6.49603e+04 Fmax= 4.29129e+02, atom= 2065
# Step=  186, Dmax= 1.6e-02 nm, Epot= -6.49980e+04 Fmax= 9.92394e+02, atom= 2065
# Step=  187, Dmax= 1.9e-02 nm, Epot= -6.50338e+04 Fmax= 1.06119e+03, atom= 2065
# Step=  188, Dmax= 2.3e-02 nm, Epot= -6.50438e+04 Fmax= 1.11704e+03, atom= 2065
# Step=  189, Dmax= 2.7e-02 nm, Epot= -6.50782e+04 Fmax= 2.26762e+03, atom= 2065
# Step=  191, Dmax= 1.6e-02 nm, Epot= -6.51062e+04 Fmax= 6.45044e+02, atom= 2087
# Step=  192, Dmax= 2.0e-02 nm, Epot= -6.51116e+04 Fmax= 3.77267e+03, atom= 2065
# Step=  193, Dmax= 2.4e-02 nm, Epot= -6.51491e+04 Fmax= 8.70523e+02, atom= 2065
# Step=  195, Dmax= 1.4e-02 nm, Epot= -6.51795e+04 Fmax= 5.57241e+02, atom= 2065
# Step=  196, Dmax= 1.7e-02 nm, Epot= -6.52049e+04 Fmax= 9.98863e+02, atom= 2065
# Step=  197, Dmax= 2.0e-02 nm, Epot= -6.52395e+04 Fmax= 1.30940e+03, atom= 2065
# Step=  198, Dmax= 2.5e-02 nm, Epot= -6.52462e+04 Fmax= 1.12137e+03, atom= 2065
# Step=  199, Dmax= 2.9e-02 nm, Epot= -6.52794e+04 Fmax= 2.80771e+03, atom= 2065
# Step=  200, Dmax= 3.5e-02 nm, Epot= -6.52811e+04 Fmax= 1.21231e+03, atom= 2065
# Step=  201, Dmax= 4.2e-02 nm, Epot= -6.52858e+04 Fmax= 6.42544e+03, atom= 2065
# Step=  202, Dmax= 5.1e-02 nm, Epot= -6.53134e+04 Fmax= 1.24029e+03, atom= 2065
# Step=  204, Dmax= 3.1e-02 nm, Epot= -6.54010e+04 Fmax= 4.45465e+02, atom= 2087
# Step=  206, Dmax= 1.8e-02 nm, Epot= -6.54222e+04 Fmax= 3.41888e+03, atom= 2065
# Step=  207, Dmax= 2.2e-02 nm, Epot= -6.54543e+04 Fmax= 7.95269e+02, atom= 2087
# Step=  209, Dmax= 1.3e-02 nm, Epot= -6.54817e+04 Fmax= 5.84913e+02, atom= 2065
# Step=  210, Dmax= 1.6e-02 nm, Epot= -6.55041e+04 Fmax= 9.09579e+02, atom= 2065
# Step=  211, Dmax= 1.9e-02 nm, Epot= -6.55342e+04 Fmax= 1.39040e+03, atom= 2065
# Step=  212, Dmax= 2.3e-02 nm, Epot= -6.55426e+04 Fmax= 1.03877e+03, atom= 2065
# Step=  213, Dmax= 2.7e-02 nm, Epot= -6.55682e+04 Fmax= 2.95171e+03, atom= 2065
# Step=  214, Dmax= 3.3e-02 nm, Epot= -6.55765e+04 Fmax= 1.14882e+03, atom= 2065
# Step=  216, Dmax= 2.0e-02 nm, Epot= -6.56291e+04 Fmax= 2.53358e+02, atom= 2087
# Step=  218, Dmax= 1.2e-02 nm, Epot= -6.56730e+04 Fmax= 1.96622e+03, atom= 2065
# Step=  219, Dmax= 1.4e-02 nm, Epot= -6.56933e+04 Fmax= 5.47616e+02, atom= 2065
# Step=  220, Dmax= 1.7e-02 nm, Epot= -6.57058e+04 Fmax= 3.14873e+03, atom= 2065
# Step=  221, Dmax= 2.0e-02 nm, Epot= -6.57354e+04 Fmax= 7.67998e+02, atom= 2065
# Step=  223, Dmax= 1.2e-02 nm, Epot= -6.57608e+04 Fmax= 5.80651e+02, atom= 2065
# Step=  224, Dmax= 1.5e-02 nm, Epot= -6.57824e+04 Fmax= 8.91264e+02, atom= 2065
# Step=  225, Dmax= 1.8e-02 nm, Epot= -6.58107e+04 Fmax= 1.25696e+03, atom= 2065
# Step=  226, Dmax= 2.1e-02 nm, Epot= -6.58198e+04 Fmax= 1.02216e+03, atom= 2065
# Step=  227, Dmax= 2.5e-02 nm, Epot= -6.58450e+04 Fmax= 2.59388e+03, atom= 2065
# Step=  228, Dmax= 3.1e-02 nm, Epot= -6.58512e+04 Fmax= 1.13585e+03, atom= 2065
# Step=  230, Dmax= 1.8e-02 nm, Epot= -6.58980e+04 Fmax= 2.42570e+02, atom= 2087
# Step=  232, Dmax= 1.1e-02 nm, Epot= -6.59358e+04 Fmax= 1.78166e+03, atom= 2065
# Step=  233, Dmax= 1.3e-02 nm, Epot= -6.59535e+04 Fmax= 5.16186e+02, atom= 2087
# Step=  234, Dmax= 1.6e-02 nm, Epot= -6.59641e+04 Fmax= 2.80083e+03, atom= 2065
# Step=  235, Dmax= 1.9e-02 nm, Epot= -6.59891e+04 Fmax= 7.31557e+02, atom= 2065
# Step=  237, Dmax= 1.1e-02 nm, Epot= -6.60103e+04 Fmax= 5.50270e+02, atom= 2065
# Step=  238, Dmax= 1.4e-02 nm, Epot= -6.60279e+04 Fmax= 8.50592e+02, atom= 2065
# Step=  239, Dmax= 1.6e-02 nm, Epot= -6.60514e+04 Fmax= 1.18205e+03, atom= 2065
# Step=  240, Dmax= 2.0e-02 nm, Epot= -6.60592e+04 Fmax= 9.82511e+02, atom= 2065
# Step=  241, Dmax= 2.4e-02 nm, Epot= -6.60799e+04 Fmax= 2.40884e+03, atom= 2065
# Step=  242, Dmax= 2.8e-02 nm, Epot= -6.60861e+04 Fmax= 1.10378e+03, atom= 2065
# Step=  244, Dmax= 1.7e-02 nm, Epot= -6.61271e+04 Fmax= 1.90874e+02, atom= 2087
# Step=  245, Dmax= 2.0e-02 nm, Epot= -6.61548e+04 Fmax= 6.73250e+03, atom= 2065
# Step=  246, Dmax= 2.4e-02 nm, Epot= -6.62332e+04 Fmax= 7.28873e+02, atom= 2065
# Step=  248, Dmax= 1.5e-02 nm, Epot= -6.62505e+04 Fmax= 1.40751e+03, atom= 2065
# Step=  249, Dmax= 1.8e-02 nm, Epot= -6.62603e+04 Fmax= 8.84426e+02, atom= 2065
# Step=  250, Dmax= 2.1e-02 nm, Epot= -6.62730e+04 Fmax= 2.54720e+03, atom= 2065
# Step=  251, Dmax= 2.5e-02 nm, Epot= -6.62848e+04 Fmax= 1.03098e+03, atom= 2065
# Step=  253, Dmax= 1.5e-02 nm, Epot= -6.63180e+04 Fmax= 1.61538e+02, atom= 5695
# Step=  254, Dmax= 1.8e-02 nm, Epot= -6.64240e+04 Fmax= 1.98121e+02, atom= 2065
# Step=  256, Dmax= 1.1e-02 nm, Epot= -6.64574e+04 Fmax= 2.12418e+03, atom= 2065
# Step=  257, Dmax= 1.3e-02 nm, Epot= -6.64786e+04 Fmax= 4.42496e+02, atom= 2087
# Step=  258, Dmax= 1.6e-02 nm, Epot= -6.64824e+04 Fmax= 3.22236e+03, atom= 2065
# Step=  259, Dmax= 1.9e-02 nm, Epot= -6.65122e+04 Fmax= 6.80362e+02, atom= 2065
# Step=  261, Dmax= 1.1e-02 nm, Epot= -6.65295e+04 Fmax= 7.43592e+02, atom= 2065
# Step=  262, Dmax= 1.4e-02 nm, Epot= -6.65401e+04 Fmax= 8.03538e+02, atom= 2065
# Step=  263, Dmax= 1.6e-02 nm, Epot= -6.65573e+04 Fmax= 1.46445e+03, atom= 2065
# Step=  264, Dmax= 2.0e-02 nm, Epot= -6.65641e+04 Fmax= 9.42242e+02, atom= 2065
# Step=  265, Dmax= 2.4e-02 nm, Epot= -6.65737e+04 Fmax= 2.89492e+03, atom= 2065
# Step=  266, Dmax= 2.8e-02 nm, Epot= -6.65848e+04 Fmax= 1.07225e+03, atom= 2065
# Step=  268, Dmax= 1.7e-02 nm, Epot= -6.66214e+04 Fmax= 1.03680e+02, atom= 5695
# Step=  269, Dmax= 2.0e-02 nm, Epot= -6.67786e+04 Fmax= 6.19674e+02, atom= 2087
# Step=  271, Dmax= 1.2e-02 nm, Epot= -6.67885e+04 Fmax= 8.99236e+02, atom= 2084
# Step=  272, Dmax= 1.5e-02 nm, Epot= -6.68010e+04 Fmax= 8.07959e+02, atom= 2065
# Step=  273, Dmax= 1.8e-02 nm, Epot= -6.68041e+04 Fmax= 1.45284e+03, atom= 2084
# Step=  274, Dmax= 2.1e-02 nm, Epot= -6.68236e+04 Fmax= 9.38600e+02, atom= 2070
# Step=  275, Dmax= 2.5e-02 nm, Epot= -6.68243e+04 Fmax= 2.80775e+03, atom= 2070
# Step=  276, Dmax= 3.0e-02 nm, Epot= -6.68351e+04 Fmax= 1.04148e+03, atom= 2070
# Step=  278, Dmax= 1.8e-02 nm, Epot= -6.68832e+04 Fmax= 5.56079e+02, atom= 2069
# Step=  280, Dmax= 1.1e-02 nm, Epot= -6.68944e+04 Fmax= 6.49127e+02, atom= 2069
# Step=  281, Dmax= 1.3e-02 nm, Epot= -6.69077e+04 Fmax= 1.02810e+03, atom= 2069
# Step=  282, Dmax= 1.6e-02 nm, Epot= -6.69171e+04 Fmax= 7.82189e+02, atom= 2069
# Step=  283, Dmax= 1.9e-02 nm, Epot= -6.69216e+04 Fmax= 1.90121e+03, atom= 2069
# Step=  284, Dmax= 2.3e-02 nm, Epot= -6.69401e+04 Fmax= 9.19890e+02, atom= 2069
# Step=  286, Dmax= 1.4e-02 nm, Epot= -6.69666e+04 Fmax= 1.27590e+02, atom= 2087
# Step=  287, Dmax= 1.6e-02 nm, Epot= -6.69730e+04 Fmax= 4.68790e+03, atom= 2065
# Step=  288, Dmax= 2.0e-02 nm, Epot= -6.70615e+04 Fmax= 5.45886e+02, atom= 2087
# Step=  290, Dmax= 1.2e-02 nm, Epot= -6.70714e+04 Fmax= 1.30498e+03, atom= 2065
# Step=  291, Dmax= 1.4e-02 nm, Epot= -6.70828e+04 Fmax= 6.98724e+02, atom= 2065
# Step=  292, Dmax= 1.7e-02 nm, Epot= -6.70850e+04 Fmax= 2.27037e+03, atom= 2065
# Step=  293, Dmax= 2.0e-02 nm, Epot= -6.71018e+04 Fmax= 8.65876e+02, atom= 2065
# Step=  295, Dmax= 1.2e-02 nm, Epot= -6.71231e+04 Fmax= 2.61624e+02, atom= 2084
# Step=  296, Dmax= 1.5e-02 nm, Epot= -6.71377e+04 Fmax= 9.13207e+02, atom= 2070
# Step=  297, Dmax= 1.8e-02 nm, Epot= -6.71674e+04 Fmax= 1.16282e+03, atom= 2065
# Step=  299, Dmax= 1.1e-02 nm, Epot= -6.71805e+04 Fmax= 4.79553e+02, atom= 2087
# Step=  300, Dmax= 1.3e-02 nm, Epot= -6.71851e+04 Fmax= 1.75741e+03, atom= 2065
# Step=  301, Dmax= 1.5e-02 nm, Epot= -6.72017e+04 Fmax= 6.68159e+02, atom= 2087
# Step=  303, Dmax= 9.1e-03 nm, Epot= -6.72163e+04 Fmax= 3.35075e+02, atom= 2065
# Step=  304, Dmax= 1.1e-02 nm, Epot= -6.72287e+04 Fmax= 7.55911e+02, atom= 2065
# Step=  305, Dmax= 1.3e-02 nm, Epot= -6.72454e+04 Fmax= 8.43251e+02, atom= 2065
# Step=  306, Dmax= 1.6e-02 nm, Epot= -6.72457e+04 Fmax= 8.74291e+02, atom= 2065
# Step=  307, Dmax= 1.9e-02 nm, Epot= -6.72574e+04 Fmax= 1.74305e+03, atom= 2065
# Step=  309, Dmax= 1.1e-02 nm, Epot= -6.72814e+04 Fmax= 3.71415e+02, atom= 2087
# Step=  311, Dmax= 6.8e-03 nm, Epot= -6.72928e+04 Fmax= 5.74123e+02, atom= 2065
# Step=  312, Dmax= 8.2e-03 nm, Epot= -6.73016e+04 Fmax= 4.92327e+02, atom= 2087
# Step=  313, Dmax= 9.8e-03 nm, Epot= -6.73118e+04 Fmax= 9.37941e+02, atom= 2065
# Step=  314, Dmax= 1.2e-02 nm, Epot= -6.73202e+04 Fmax= 6.34328e+02, atom= 2087
# Step=  315, Dmax= 1.4e-02 nm, Epot= -6.73256e+04 Fmax= 1.59899e+03, atom= 2065
# Step=  316, Dmax= 1.7e-02 nm, Epot= -6.73367e+04 Fmax= 7.90880e+02, atom= 2087
# Step=  318, Dmax= 1.0e-02 nm, Epot= -6.73564e+04 Fmax= 2.27842e+02, atom= 2084
# Step=  319, Dmax= 1.2e-02 nm, Epot= -6.73768e+04 Fmax= 8.37452e+02, atom= 2070
# Step=  320, Dmax= 1.5e-02 nm, Epot= -6.73972e+04 Fmax= 8.37078e+02, atom= 2065
# Step=  322, Dmax= 8.8e-03 nm, Epot= -6.74071e+04 Fmax= 4.42038e+02, atom= 2087
# Step=  323, Dmax= 1.1e-02 nm, Epot= -6.74139e+04 Fmax= 1.27286e+03, atom= 2065
# Step=  324, Dmax= 1.3e-02 nm, Epot= -6.74259e+04 Fmax= 6.06150e+02, atom= 2087
# Step=  326, Dmax= 7.6e-03 nm, Epot= -6.74391e+04 Fmax= 2.33597e+02, atom= 2065
# Step=  327, Dmax= 9.1e-03 nm, Epot= -6.74546e+04 Fmax= 6.81102e+02, atom= 2065
# Step=  328, Dmax= 1.1e-02 nm, Epot= -6.74706e+04 Fmax= 6.39864e+02, atom= 2065
# Step=  329, Dmax= 1.3e-02 nm, Epot= -6.74727e+04 Fmax= 7.93188e+02, atom= 2065
# Step=  330, Dmax= 1.6e-02 nm, Epot= -6.74861e+04 Fmax= 1.31141e+03, atom= 2065
# Step=  332, Dmax= 9.4e-03 nm, Epot= -6.75029e+04 Fmax= 3.26955e+02, atom= 2087
# Step=  333, Dmax= 1.1e-02 nm, Epot= -6.75050e+04 Fmax= 1.81518e+03, atom= 2065
# Step=  334, Dmax= 1.4e-02 nm, Epot= -6.75262e+04 Fmax= 5.43877e+02, atom= 2087
# Step=  336, Dmax= 8.1e-03 nm, Epot= -6.75379e+04 Fmax= 4.69764e+02, atom= 2065
# Step=  337, Dmax= 9.8e-03 nm, Epot= -6.75452e+04 Fmax= 6.46574e+02, atom= 2087
# Step=  338, Dmax= 1.2e-02 nm, Epot= -6.75567e+04 Fmax= 9.23756e+02, atom= 2065
# Step=  339, Dmax= 1.4e-02 nm, Epot= -6.75602e+04 Fmax= 7.74529e+02, atom= 2065
# Step=  340, Dmax= 1.7e-02 nm, Epot= -6.75650e+04 Fmax= 1.75164e+03, atom= 2065
# Step=  341, Dmax= 2.0e-02 nm, Epot= -6.75709e+04 Fmax= 9.17280e+02, atom= 2065
# Step=  343, Dmax= 1.2e-02 nm, Epot= -6.76013e+04 Fmax= 1.18129e+02, atom= 2084
# Step=  344, Dmax= 1.5e-02 nm, Epot= -6.76586e+04 Fmax= 9.60384e+02, atom= 2070
# Step=  345, Dmax= 1.8e-02 nm, Epot= -6.76827e+04 Fmax= 6.15258e+02, atom= 2084
# Step=  347, Dmax= 1.1e-02 nm, Epot= -6.76880e+04 Fmax= 6.47408e+02, atom= 2070
# Step=  348, Dmax= 1.3e-02 nm, Epot= -6.76970e+04 Fmax= 1.06892e+03, atom= 2084
# Step=  349, Dmax= 1.5e-02 nm, Epot= -6.76989e+04 Fmax= 7.93692e+02, atom= 2065
# Step=  350, Dmax= 1.8e-02 nm, Epot= -6.76993e+04 Fmax= 2.08613e+03, atom= 2065
# Step=  351, Dmax= 2.2e-02 nm, Epot= -6.77089e+04 Fmax= 9.41424e+02, atom= 2065
# Step=  353, Dmax= 1.3e-02 nm, Epot= -6.77429e+04 Fmax= 9.77719e+01, atom= 2070
#
# writing lowest energy coordinates.
#
# Back Off! I just backed up m.gro to ./#m.gro.1#
#
# Steepest Descents converged to Fmax < 100 in 354 steps
# Potential Energy  = -6.7742945e+04
# Maximum force     =  9.7771858e+01 on atom 2070
# Norm of force     =  1.6996350e+01
#
# GROMACS reminds you: "Never, I said never, compare with experiment" (Magnus Bergh)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx grompp -f /mnt/f/BILAYERS/MDPs/rel_310.mdp -c m.gro -p topol.top -o r.tpr -n index.ndx -maxwarn 5
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
#
# WARNING 1 [file /mnt/f/BILAYERS/MDPs/rel_310.mdp]:
#   The Berendsen thermostat does not generate the correct kinetic energy
#   distribution, and should not be used for new production simulations (in
#   our opinion). We would recommend the V-rescale thermostat.
#
#
# WARNING 2 [file /mnt/f/BILAYERS/MDPs/rel_310.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   For isotropic scaling we would recommend the C-rescale barostat that also
#   ensures fast relaxation without oscillations, and for anisotropic scaling
#   you likely want to use the Parrinello-Rahman barostat.
#
# Number of degrees of freedom in T-Coupling group Lipids is 1799.14
# Number of degrees of freedom in T-Coupling group Solvent is 4473.86
#
# There were 2 WARNINGs
#
# GROMACS reminds you: "The use of COBOL cripples the mind; its teaching should therefore be regarded as a criminal offense." (Edsger Dijkstra)
#
#                       :-) GROMACS - gmx mdrun, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx mdrun -v -deffnm r -nt 5 -rdd 1.6
#
#
# Back Off! I just backed up r.log to ./#r.log.1#
# Reading file r.tpr, VERSION 2023.1 (single precision)
# Changing nstlist from 20 to 40, rlist from 1.156 to 1.257
#
# Using 1 MPI thread
# Using 5 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cpus
#       and the -pin option is set to auto: will not pin threads to cpus.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
#
# Back Off! I just backed up r.xtc to ./#r.xtc.1#
#
# Back Off! I just backed up r.edr to ./#r.edr.1#
# starting mdrun 'INSANE! Membrane UpperLeaflet>CER6:POPC=30.0:70.0 LowerLeaflet>CER6:POPC=30.0:70.0'
# 1000000 steps,  10000.0 ps.
# step 1000, remaining wall clock time:   127 s
# Setting the LD random seed to -654738705
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Setting gen_seed to -1562916997
#
# Velocities were taken from a Maxwell distribution at 310 K
#
# Determining Verlet buffer for a tolerance of 0.002 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.199 nm, buffer size 0.099 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.156 nm, buffer size 0.056 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 112 Mb of data
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
#
# Back Off! I just backed up r.gro to ./#r.gro.1#
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:      652.305      130.473      500.0
#                  (ns/day)    (hour/ns)
# Performance:     6622.075        0.004
#
# GROMACS reminds you: "What Kind Of Guru are You, Anyway ?" (F. Zappa)
#
#                       :-) GROMACS - gmx grompp, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx grompp -f /mnt/f/BILAYERS/MDPs/prod_310.mdp -c r.gro -p topol.top -o p.tpr -n index.ndx -maxwarn 5
#
# Ignoring obsolete mdp entry 'title'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc_precision' by 'compressed-x-precision'
# Number of degrees of freedom in T-Coupling group Lipids is 1799.14
# Number of degrees of freedom in T-Coupling group Solvent is 4473.86
#
# GROMACS reminds you: "What Kind Of Guru are You, Anyway ?" (F. Zappa)
#
#                       :-) GROMACS - gmx mdrun, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx mdrun -v -deffnm p -nt 5 -rdd 1.6
#
#
# Back Off! I just backed up p.log to ./#p.log.1#
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Changing nstlist from 20 to 25, rlist from 1.252 to 1.31
#
# Using 1 MPI thread
# Using 5 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cpus
#       and the -pin option is set to auto: will not pin threads to cpus.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
#
# Sorry couldn't backup p.xtc to ./#p.xtc.1#
#
# Back Off! I just backed up p.edr to ./#p.edr.1#
# starting mdrun 'INSANE! Membrane UpperLeaflet>CER6:POPC=30.0:70.0 LowerLeaflet>CER6:POPC=30.0:70.0'
# 100000000 steps, 2000000.0 ps.
# step 800, will finish Mon Feb 10 22:23:32 2025
# Setting the LD random seed to -11542597
#
# Generated 844 of the 356590 non-bonded parameter combinations
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'CER6'
#
# Excluding 1 bonded neighbours molecule type 'POPC'
#
# Excluding 1 bonded neighbours molecule type 'W'
#
# Excluding 1 bonded neighbours molecule type 'NA'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# Determining Verlet buffer for a tolerance of 0.002 kJ/mol/ps at 310 K
#
# Calculated rlist for 1x1 atom pair-list as 1.334 nm, buffer size 0.234 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.252 nm, buffer size 0.152 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# This run will generate roughly 208 Mb of data
# step 99999900, remaining wall clock time:     0 s
# Writing final coordinates.
#
# Back Off! I just backed up p.gro to ./#p.gro.1#
# step 100000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    65524.097    13104.832      500.0
#                          3h38:24
#                  (ns/day)    (hour/ns)
# Performance:    13185.977        0.002
#
# GROMACS reminds you: "Here are all the 'gmx' tools... but no gmx writethesis" (Christian Blau)

# %%
    ###Correct for the PBC
    p = subprocess.Popen('gmx trjconv -f p.xtc -s p.tpr -o pbc.gro -pbc mol -b 0 -e 0'
                         , stdin=subprocess.PIPE, shell=True, universal_newlines=True)
    p.communicate('CER')
    p.wait()
    ###Correct for the PBC
    p = subprocess.Popen('gmx trjconv -f p.xtc -s p.tpr -o pbc.xtc -pbc mol'
                         , stdin=subprocess.PIPE, shell=True, universal_newlines=True)
    p.communicate('CER')
    p.wait()
# Out:
#                      :-) GROMACS - gmx trjconv, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx trjconv -f p.xtc -s p.tpr -o pbc.gro -pbc mol -b 0 -e 0
#
# Will write gro: Coordinate file in Gromos-87 format
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  2092 elements
# Group     1 (          Other) has  2092 elements
# Group     2 (           CER6) has   160 elements
# Group     3 (           POPC) has   600 elements
# Group     4 (              W) has  1304 elements
# Group     5 (            ION) has    28 elements
# Reading frame       0 time    0.000
# Precision of p.xtc is 0.01 (nm)
#
# Back Off! I just backed up pbc.gro to ./#pbc.gro.1#
# Last frame          0 time    0.000
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "Here are all the 'gmx' tools... but no gmx writethesis" (Christian Blau)
#
#                      :-) GROMACS - gmx trjconv, 2023.1 (-:
#
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /mnt/f/BILAYERS/CER6/gromacs_MAP2/CG_BL
# Command line:
#   gmx trjconv -f p.xtc -s p.tpr -o pbc.xtc -pbc mol
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Reading file p.tpr, VERSION 2023.1 (single precision)
# Group     0 (         System) has  2092 elements
# Group     1 (          Other) has  2092 elements
# Group     2 (           CER6) has   160 elements
# Group     3 (           POPC) has   600 elements
# Group     4 (              W) has  1304 elements
# Group     5 (            ION) has    28 elements
# Reading frame       0 time    0.000
# Precision of p.xtc is 0.01 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up pbc.xtc to ./#pbc.xtc.1#
# Reading frame      90 time 18000.000    ->  frame     89 time 17800.000
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 2: 'CER6'
# Reading frame    9000 time 1800000.000    ->  frame   8999 time 1799800.000
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 2: 'CER6'
# Last frame      10000 time 2000000.000    ->  frame   9999 time 1999800.000
#  ->  frame  10000 time 2000000.000
# Last written: frame  10000 time 2000000.000
#
#
# GROMACS reminds you: "There is no reason for any individual to have a computer in his home." (Ken Olsen, head of Digital Equipment Corp.)
# 0

# %%
#os.chdir('CG_WAT')
## Open AA   
u_aa = md.Universe('../cg_good.gro',
                   '../cg.xtc')

## Open CG
u_cg = md.Universe('pbc.gro', 'pbc.xtc')
# Out:
# /home/ltr/anaconda3/envs/jupyter_env/lib/python3.10/site-packages/MDAnalysis/coordinates/XDR.py:240: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn("Reload offsets from trajectory\n "

# %%
ang_hist_aa, dist_hist_aa, ang_aa, dist_aa = measure_bonded_terms_simple(dist_tgts, ang_tgts, u_aa, bead_names, resname, 'AA', stride=10)
# Out:
# Calculating distributions...
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
ang_hist_cg, dist_hist_cg, ang_cg, dist_cg = measure_bonded_terms_simple(dist_tgts, ang_tgts, u_cg, bead_names, 'CER6', 'CG', stride=10)
# Out:
# Calculating distributions...
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
for bond in List_bonds:
    HAA,BAA = np.histogram(np.array(dist_aa)[bond,:], bins=bins_dist, density=True)
    HCG,BCG = np.histogram(np.array(dist_cg)[bond,:], bins=bins_dist, density=True)

    plt.plot(bins_dist_x, HAA, label='AA', color='green')
    plt.plot(bins_dist_x, HCG, label='CG', color='orange')

    title = ' '.join(i for i in dist_tgts[bond[0]])
    plt.title(title) 
    plt.xlabel('Bond (nm)')
    plt.ylabel('Probability density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
    plt.savefig('{}_BL_bond.png'.format(title), dpi=300, bbox_inches='tight')
    plt.show()

# %%
for angle in List_angles:
    HAA,BAA = np.histogram(np.array(ang_aa)[angle,:], bins=bins_angl, density=True)
    HCG,BCG = np.histogram(np.array(ang_cg)[angle,:], bins=bins_angl, density=True)

    plt.plot(bins_angl_x, HAA, label='AA', color='green')
    plt.plot(bins_angl_x, HCG, label='CG', color='orange')
    title = ' '.join(i for i in ang_tgts[angle[0]])
    plt.title(title) 
    plt.xlabel('Angle (°)')
    plt.ylabel('Probability density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
    plt.savefig('{}_BL_angle.png'.format(title), dpi=300, bbox_inches='tight')
    plt.show()

# %%
for dihed in List_dihed:

    HAA,BAA = np.histogram(np.array(dihed_aa)[dihed,:], bins=bins_dihed, density=True)
    HCG,BCG = np.histogram(np.array(dihed_cg)[dihed,:], bins=bins_dihed, density=True)


    plt.plot(bins_dihed_x, HAA, label='AA')
    plt.plot(bins_dihed_x, HCG, label='CG')
    title = ' '.join(i for i in dihed_tgts[dihed[0]])
    plt.title(title) 
    plt.xlabel('Dihedral (°)')
    plt.ylabel('Probability density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
    plt.savefig('{}_BL_dihedral.png'.format(title), dpi=300, bbox_inches='tight')
    plt.show()

# %%
## Check average APL with AA sims. You have the same amount of POPC in there, so it should be a fine estimate

# %% [markdown]
# ## APL

# %%
u_aa = md.Universe('../step6.0_minimization.gro',
                   '../AA_whole.xtc')

## Open CG
u_cg = md.Universe('p.gro', 'p.xtc')
# Out:
# /home/ltr/anaconda3/envs/jupyter_env/lib/python3.10/site-packages/MDAnalysis/coordinates/XDR.py:240: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn("Reload offsets from trajectory\n "

# %%
APL_aa = []
for ts in u_aa.trajectory[::10]:
    x,y = u_aa.dimensions[:2]
    no_lipids_leaflet = int(np.unique(u_aa.select_atoms('all and not resname NA CL SOD CLA TIP3P TIP3').resids).shape[0]/2)
    A = x*y
    apl = A / no_lipids_leaflet
    APL_aa.append(apl)

# %%
APL_cg = []
for ts in u_cg.trajectory[::10]:
    x,y = u_cg.dimensions[:2]
    no_lipids_leaflet = int(np.unique(u_cg.select_atoms('all and not resname ION NA CL W WN WO').resids).shape[0]/2)
    A = x*y
    apl = A / no_lipids_leaflet
    APL_cg.append(apl)

# %%
print (np.average(APL_aa), np.std(APL_aa))
print (np.average(APL_cg), np.std(APL_cg))
# Out:
# 61.88339 1.688749
# 57.52231 1.8658321

# %%
(float(np.average(APL_aa)/np.average(APL_cg)) - 1) * 100
# Out:
# 7.581543922424316

# %%
### Conclusion, keep GLB as a regular bead and dont use a small bead

# %%
## Then make the final itps
